# %%
##################################################
#################### LSTM  #######################
##################################################
import numpy as np
import matplotlib.pyplot as plt
import math
import json
from netCDF4 import Dataset
from functionsLSTM import *
from scipy import fftpack
from datetime import datetime
import multiprocessing
from joblib import Parallel, delayed
from tqdm import tqdm
# np.random.seed(42)

num_cores = multiprocessing.cpu_count()
print('Number of cores:',num_cores)

# Define other parameters of the problem
n_pc = 150         # number of PCs
n_record = 50000   # total records
n_maxtrain = 40000 # maximum possible length of training data
n_test = n_record - n_maxtrain # length of the test data
test0_idx = n_maxtrain              # test data start index
dt = 10            # temporal resolution

#### Load the pcs ####
f = 'psi1_DG_0_500K_100days_filtered_150PCs.dat'
fpath = os.getcwd() + '/../' + f
pcs = dlmread(fpath,n_record,n_pc)
pcs = center(pcs)
# get the test dataset
test_data = pcs[test0_idx:test0_idx+n_test, :]
 
#### Load the EOFs ####
nx = 513; ny=513
eoffile = os.getcwd() + '/../psi1_DG_0_500K_100days_filtered_150EOFs.nc'
fid = Dataset(eoffile,'r')
eofs = fid.variables['EOFs'][:n_pc,:,:]
eofs = eofs.reshape((n_pc, nx*ny))
# Out:
# Number of cores: 24

# %%
#################################################################
### Sensitivity analysis of training length to the performance ##
#################################################################
# check the RMSE on the test data for next time step forecast

n_mintrain = 1000
n_train_inc = 1000

n_train = np.arange(n_mintrain, n_maxtrain+1, n_train_inc, dtype='int')
rmse_test = np.zeros((len(n_train), n_pc)) 

hyperparams = {'numhidunits':100, 'loss':'mae', 
               'optimizer':'adam', 'epochs':20,
               'numhidlayer':2, 'activation':'tanh',
               'isdrop':True, 'dropmag':0.2, 
               'validation_split':0.2}

ypred_LSTM = np.zeros((100, n_pc))

for i, trainlen in enumerate(n_train):
    print('Training length:',trainlen)
    # prepare the training data
    [x_train, y_train, scaler] = trainingdata(pcs, n_pc, trainlen, 'standard_top_pc')
    # perform LSTM
    model, history = fitLSTM(x_train, y_train, n_pc, **hyperparams)
    # check the performance on the test dataset
    normalized_test_data = scaler.transform(test_data)
    for k in range(100):
        ypred_LSTM[k,:] = np.squeeze(model.predict(np.expand_dims(normalized_test_data[k:k+1,:], axis=0), batch_size=1))
    # compute the rms error
    rmse_test[i,:] = np.sum((ypred_LSTM[:-1,:] - normalized_test_data[1:100,:])**2, axis=0)
# Out:
# Training length: 1000
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_15 (LSTM)               (None, 1, 100)            100400
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_16 (LSTM)               (None, 1, 100)            80400
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_17 (LSTM)               (None, 100)               80400
# _________________________________________________________________
# dense_5 (Dense)              (None, 150)               15150
# =================================================================
# Total params: 276,350
# Trainable params: 276,350
# Non-trainable params: 0
# _________________________________________________________________
# Train on 799 samples, validate on 200 samples
# Epoch 1/20
# 799/799 - 8s - loss: 0.3774 - val_loss: 0.2014
# Epoch 2/20
# 799/799 - 0s - loss: 0.1292 - val_loss: 0.1200
# Epoch 3/20
# 799/799 - 0s - loss: 0.1066 - val_loss: 0.1174
# Epoch 4/20
# 799/799 - 0s - loss: 0.1057 - val_loss: 0.1174
# Epoch 5/20
# 799/799 - 0s - loss: 0.1051 - val_loss: 0.1173
# Epoch 6/20
# 799/799 - 0s - loss: 0.1050 - val_loss: 0.1174
# Epoch 7/20
# 799/799 - 0s - loss: 0.1046 - val_loss: 0.1174
# Epoch 8/20
# 799/799 - 0s - loss: 0.1046 - val_loss: 0.1174
# Epoch 9/20
# 799/799 - 0s - loss: 0.1043 - val_loss: 0.1174
# Epoch 10/20
# 799/799 - 0s - loss: 0.1041 - val_loss: 0.1173
# Epoch 11/20
# 799/799 - 0s - loss: 0.1042 - val_loss: 0.1174
# Epoch 12/20
# 799/799 - 0s - loss: 0.1038 - val_loss: 0.1173
# Epoch 13/20
# 799/799 - 0s - loss: 0.1037 - val_loss: 0.1175
# Epoch 14/20
# 799/799 - 0s - loss: 0.1036 - val_loss: 0.1175
# Epoch 15/20
# 799/799 - 0s - loss: 0.1035 - val_loss: 0.1174
# Epoch 16/20
# 799/799 - 0s - loss: 0.1034 - val_loss: 0.1174
# Epoch 17/20
# 799/799 - 0s - loss: 0.1033 - val_loss: 0.1174
# Epoch 18/20
# 799/799 - 0s - loss: 0.1032 - val_loss: 0.1174
# Epoch 19/20
# 799/799 - 0s - loss: 0.1032 - val_loss: 0.1174
# Epoch 20/20
# 799/799 - 0s - loss: 0.1030 - val_loss: 0.1174
# Training length: 2000
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_18 (LSTM)               (None, 1, 100)            100400
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_19 (LSTM)               (None, 1, 100)            80400
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_20 (LSTM)               (None, 100)               80400
# _________________________________________________________________
# dense_6 (Dense)              (None, 150)               15150
# =================================================================
# Total params: 276,350
# Trainable params: 276,350
# Non-trainable params: 0
# _________________________________________________________________
# Train on 1599 samples, validate on 400 samples
# Epoch 1/20
# 1599/1599 - 8s - loss: 0.1017 - val_loss: 0.1056
# Epoch 2/20
# 1599/1599 - 1s - loss: 0.0992 - val_loss: 0.1054
# Epoch 3/20
# 1599/1599 - 1s - loss: 0.0981 - val_loss: 0.1055
# Epoch 4/20
# 1599/1599 - 1s - loss: 0.0957 - val_loss: 0.1038
# Epoch 5/20
# 1599/1599 - 1s - loss: 0.0927 - val_loss: 0.1022
# Epoch 6/20
# 1599/1599 - 1s - loss: 0.0898 - val_loss: 0.1005
# Epoch 7/20
# 1599/1599 - 1s - loss: 0.0871 - val_loss: 0.0989
# Epoch 8/20
# 1599/1599 - 1s - loss: 0.0851 - val_loss: 0.0978
# Epoch 9/20
# 1599/1599 - 1s - loss: 0.0834 - val_loss: 0.0966
# Epoch 10/20
# 1599/1599 - 1s - loss: 0.0820 - val_loss: 0.0961
# Epoch 11/20
# 1599/1599 - 1s - loss: 0.0805 - val_loss: 0.0948
# Epoch 12/20
# 1599/1599 - 1s - loss: 0.0793 - val_loss: 0.0939
# Epoch 13/20
# 1599/1599 - 1s - loss: 0.0777 - val_loss: 0.0934
# Epoch 14/20
# 1599/1599 - 1s - loss: 0.0766 - val_loss: 0.0925
# Epoch 15/20
# 1599/1599 - 1s - loss: 0.0755 - val_loss: 0.0920
# Epoch 16/20
# 1599/1599 - 1s - loss: 0.0743 - val_loss: 0.0918
# Epoch 17/20
# 1599/1599 - 1s - loss: 0.0736 - val_loss: 0.0915
# Epoch 18/20
# 1599/1599 - 1s - loss: 0.0727 - val_loss: 0.0908
# Epoch 19/20
# 1599/1599 - 1s - loss: 0.0719 - val_loss: 0.0903
# Epoch 20/20
# 1599/1599 - 1s - loss: 0.0711 - val_loss: 0.0895
# Training length: 3000
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_21 (LSTM)               (None, 1, 100)            100400
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_22 (LSTM)               (None, 1, 100)            80400
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_23 (LSTM)               (None, 100)               80400
# _________________________________________________________________
# dense_7 (Dense)              (None, 150)               15150
# =================================================================
# Total params: 276,350
# Trainable params: 276,350
# Non-trainable params: 0
# _________________________________________________________________
# Train on 2399 samples, validate on 600 samples
# Epoch 1/20
# 2399/2399 - 8s - loss: 0.0979 - val_loss: 0.0892
# Epoch 2/20
# 2399/2399 - 1s - loss: 0.0936 - val_loss: 0.0891
# Epoch 3/20
# 2399/2399 - 1s - loss: 0.0932 - val_loss: 0.0889
# Epoch 4/20
# 2399/2399 - 1s - loss: 0.0924 - val_loss: 0.0884
# Epoch 5/20
# 2399/2399 - 1s - loss: 0.0904 - val_loss: 0.0870
# Epoch 6/20
# 2399/2399 - 1s - loss: 0.0872 - val_loss: 0.0851
# Epoch 7/20
# 2399/2399 - 1s - loss: 0.0845 - val_loss: 0.0839
# Epoch 8/20
# 2399/2399 - 1s - loss: 0.0818 - val_loss: 0.0824
# Epoch 9/20
# 2399/2399 - 1s - loss: 0.0797 - val_loss: 0.0820
# Epoch 10/20
# 2399/2399 - 1s - loss: 0.0781 - val_loss: 0.0803
# Epoch 11/20
# 2399/2399 - 1s - loss: 0.0771 - val_loss: 0.0789
# Epoch 12/20
# 2399/2399 - 1s - loss: 0.0753 - val_loss: 0.0777
# Epoch 13/20
# 2399/2399 - 1s - loss: 0.0737 - val_loss: 0.0771
# Epoch 14/20
# 2399/2399 - 1s - loss: 0.0727 - val_loss: 0.0760
# Epoch 15/20
# 2399/2399 - 1s - loss: 0.0718 - val_loss: 0.0759
# Epoch 16/20
# 2399/2399 - 1s - loss: 0.0705 - val_loss: 0.0747
# Epoch 17/20
# 2399/2399 - 1s - loss: 0.0693 - val_loss: 0.0743
# Epoch 18/20
# 2399/2399 - 1s - loss: 0.0684 - val_loss: 0.0734
# Epoch 19/20
# 2399/2399 - 1s - loss: 0.0676 - val_loss: 0.0734
# Epoch 20/20
# 2399/2399 - 1s - loss: 0.0671 - val_loss: 0.0726
# Training length: 4000
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_24 (LSTM)               (None, 1, 100)            100400
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_25 (LSTM)               (None, 1, 100)            80400
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_26 (LSTM)               (None, 100)               80400
# _________________________________________________________________
# dense_8 (Dense)              (None, 150)               15150
# =================================================================
# Total params: 276,350
# Trainable params: 276,350
# Non-trainable params: 0
# _________________________________________________________________
# Train on 3199 samples, validate on 800 samples
# Epoch 1/20
# 3199/3199 - 9s - loss: 0.1023 - val_loss: 0.0960
# Epoch 2/20
# 3199/3199 - 1s - loss: 0.1007 - val_loss: 0.0950
# Epoch 3/20
# 3199/3199 - 1s - loss: 0.0975 - val_loss: 0.0927
# Epoch 4/20
# 3199/3199 - 1s - loss: 0.0928 - val_loss: 0.0900
# Epoch 5/20
# 3199/3199 - 1s - loss: 0.0894 - val_loss: 0.0884
# Epoch 6/20
# 3199/3199 - 1s - loss: 0.0866 - val_loss: 0.0864
# Epoch 7/20
# 3199/3199 - 1s - loss: 0.0846 - val_loss: 0.0846
# Epoch 8/20
# 3199/3199 - 1s - loss: 0.0827 - val_loss: 0.0833
# Epoch 9/20
# 3199/3199 - 1s - loss: 0.0809 - val_loss: 0.0819
# Epoch 10/20
# 3199/3199 - 1s - loss: 0.0795 - val_loss: 0.0808
# Epoch 11/20
# 3199/3199 - 1s - loss: 0.0784 - val_loss: 0.0800
# Epoch 12/20
# 3199/3199 - 1s - loss: 0.0775 - val_loss: 0.0793
# Epoch 13/20
# 3199/3199 - 1s - loss: 0.0763 - val_loss: 0.0787
# Epoch 14/20
# 3199/3199 - 1s - loss: 0.0757 - val_loss: 0.0783
# Epoch 15/20
# 3199/3199 - 1s - loss: 0.0748 - val_loss: 0.0775
# Epoch 16/20
# 3199/3199 - 1s - loss: 0.0742 - val_loss: 0.0773
# Epoch 17/20
# 3199/3199 - 1s - loss: 0.0736 - val_loss: 0.0768
# Epoch 18/20
# 3199/3199 - 1s - loss: 0.0730 - val_loss: 0.0769
# Epoch 19/20
# 3199/3199 - 1s - loss: 0.0725 - val_loss: 0.0764
# Epoch 20/20
# 3199/3199 - 1s - loss: 0.0722 - val_loss: 0.0765
# Training length: 5000
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_27 (LSTM)               (None, 1, 100)            100400
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_28 (LSTM)               (None, 1, 100)            80400
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_29 (LSTM)               (None, 100)               80400
# _________________________________________________________________
# dense_9 (Dense)              (None, 150)               15150
# =================================================================
# Total params: 276,350
# Trainable params: 276,350
# Non-trainable params: 0
# _________________________________________________________________
# Train on 3999 samples, validate on 1000 samples
# Epoch 1/20
# 3999/3999 - 9s - loss: 0.1022 - val_loss: 0.1026
# Epoch 2/20
# 3999/3999 - 1s - loss: 0.0995 - val_loss: 0.1018
# Epoch 3/20
# 3999/3999 - 1s - loss: 0.0975 - val_loss: 0.0991
# Epoch 4/20
# 3999/3999 - 1s - loss: 0.0933 - val_loss: 0.0944
# Epoch 5/20
# 3999/3999 - 1s - loss: 0.0888 - val_loss: 0.0912
# Epoch 6/20
# 3999/3999 - 1s - loss: 0.0859 - val_loss: 0.0891
# Epoch 7/20
# 3999/3999 - 1s - loss: 0.0838 - val_loss: 0.0871
# Epoch 8/20
# 3999/3999 - 1s - loss: 0.0817 - val_loss: 0.0854
# Epoch 9/20
# 3999/3999 - 1s - loss: 0.0800 - val_loss: 0.0838
# Epoch 10/20
# 3999/3999 - 1s - loss: 0.0785 - val_loss: 0.0829
# Epoch 11/20
# 3999/3999 - 1s - loss: 0.0773 - val_loss: 0.0823
# Epoch 12/20
# 3999/3999 - 1s - loss: 0.0762 - val_loss: 0.0812
# Epoch 13/20
# 3999/3999 - 1s - loss: 0.0751 - val_loss: 0.0802
# Epoch 14/20
# 3999/3999 - 1s - loss: 0.0743 - val_loss: 0.0797
# Epoch 15/20
# 3999/3999 - 1s - loss: 0.0735 - val_loss: 0.0794
# Epoch 16/20
# 3999/3999 - 1s - loss: 0.0729 - val_loss: 0.0788
# Epoch 17/20
# 3999/3999 - 1s - loss: 0.0720 - val_loss: 0.0788
# Epoch 18/20
# 3999/3999 - 1s - loss: 0.0715 - val_loss: 0.0783
# Epoch 19/20
# 3999/3999 - 1s - loss: 0.0711 - val_loss: 0.0784
# Epoch 20/20
# 3999/3999 - 1s - loss: 0.0703 - val_loss: 0.0778
# Training length: 6000
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_30 (LSTM)               (None, 1, 100)            100400
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_31 (LSTM)               (None, 1, 100)            80400
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_32 (LSTM)               (None, 100)               80400
# _________________________________________________________________
# dense_10 (Dense)             (None, 150)               15150
# =================================================================
# Total params: 276,350
# Trainable params: 276,350
# Non-trainable params: 0
# _________________________________________________________________
# Train on 4799 samples, validate on 1200 samples
# Epoch 1/20
# 4799/4799 - 9s - loss: 0.1022 - val_loss: 0.1034
# Epoch 2/20
# 4799/4799 - 2s - loss: 0.0991 - val_loss: 0.1000
# Epoch 3/20
# 4799/4799 - 2s - loss: 0.0936 - val_loss: 0.0955
# Epoch 4/20
# 4799/4799 - 2s - loss: 0.0899 - val_loss: 0.0924
# Epoch 5/20
# 4799/4799 - 2s - loss: 0.0869 - val_loss: 0.0902
# Epoch 6/20
# 4799/4799 - 2s - loss: 0.0847 - val_loss: 0.0884
# Epoch 7/20
# 4799/4799 - 2s - loss: 0.0829 - val_loss: 0.0873
# Epoch 8/20
# 4799/4799 - 2s - loss: 0.0817 - val_loss: 0.0861
# Epoch 9/20
# 4799/4799 - 2s - loss: 0.0805 - val_loss: 0.0852
# Epoch 10/20
# 4799/4799 - 2s - loss: 0.0796 - val_loss: 0.0842
# Epoch 11/20
# 4799/4799 - 2s - loss: 0.0787 - val_loss: 0.0836
# Epoch 12/20
# 4799/4799 - 2s - loss: 0.0779 - val_loss: 0.0829
# Epoch 13/20
# 4799/4799 - 2s - loss: 0.0771 - val_loss: 0.0820
# Epoch 14/20
# 4799/4799 - 2s - loss: 0.0762 - val_loss: 0.0813
# Epoch 15/20
# 4799/4799 - 2s - loss: 0.0756 - val_loss: 0.0807
# Epoch 16/20
# 4799/4799 - 2s - loss: 0.0751 - val_loss: 0.0803
# Epoch 17/20
# 4799/4799 - 2s - loss: 0.0743 - val_loss: 0.0798
# Epoch 18/20
# 4799/4799 - 2s - loss: 0.0738 - val_loss: 0.0791
# Epoch 19/20
# 4799/4799 - 2s - loss: 0.0733 - val_loss: 0.0787
# Epoch 20/20
# 4799/4799 - 2s - loss: 0.0728 - val_loss: 0.0784
# Training length: 7000
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_33 (LSTM)               (None, 1, 100)            100400
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_34 (LSTM)               (None, 1, 100)            80400
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_35 (LSTM)               (None, 100)               80400
# _________________________________________________________________
# dense_11 (Dense)             (None, 150)               15150
# =================================================================
# Total params: 276,350
# Trainable params: 276,350
# Non-trainable params: 0
# _________________________________________________________________
# Train on 5599 samples, validate on 1400 samples
# Epoch 1/20
# 5599/5599 - 9s - loss: 0.1064 - val_loss: 0.1000
# Epoch 2/20
# 5599/5599 - 2s - loss: 0.1037 - val_loss: 0.0962
# Epoch 3/20
# 5599/5599 - 2s - loss: 0.0960 - val_loss: 0.0901
# Epoch 4/20
# 5599/5599 - 2s - loss: 0.0906 - val_loss: 0.0875
# Epoch 5/20
# 5599/5599 - 2s - loss: 0.0879 - val_loss: 0.0852
# Epoch 6/20
# 5599/5599 - 2s - loss: 0.0858 - val_loss: 0.0837
# Epoch 7/20
# 5599/5599 - 2s - loss: 0.0843 - val_loss: 0.0826
# Epoch 8/20
# 5599/5599 - 2s - loss: 0.0826 - val_loss: 0.0810
# Epoch 9/20
# 5599/5599 - 2s - loss: 0.0812 - val_loss: 0.0798
# Epoch 10/20
# 5599/5599 - 2s - loss: 0.0802 - val_loss: 0.0788
# Epoch 11/20
# 5599/5599 - 2s - loss: 0.0791 - val_loss: 0.0779
# Epoch 12/20
# 5599/5599 - 2s - loss: 0.0783 - val_loss: 0.0771
# Epoch 13/20
# 5599/5599 - 2s - loss: 0.0775 - val_loss: 0.0765
# Epoch 14/20
# 5599/5599 - 2s - loss: 0.0769 - val_loss: 0.0760
# Epoch 15/20
# 5599/5599 - 2s - loss: 0.0764 - val_loss: 0.0754
# Epoch 16/20
# 5599/5599 - 2s - loss: 0.0757 - val_loss: 0.0747
# Epoch 17/20
# 5599/5599 - 2s - loss: 0.0752 - val_loss: 0.0748
# Epoch 18/20
# 5599/5599 - 2s - loss: 0.0748 - val_loss: 0.0740
# Epoch 19/20
# 5599/5599 - 2s - loss: 0.0743 - val_loss: 0.0738
# Epoch 20/20
# 5599/5599 - 2s - loss: 0.0740 - val_loss: 0.0733
# Training length: 8000
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_36 (LSTM)               (None, 1, 100)            100400
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_37 (LSTM)               (None, 1, 100)            80400
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_38 (LSTM)               (None, 100)               80400
# _________________________________________________________________
# dense_12 (Dense)             (None, 150)               15150
# =================================================================
# Total params: 276,350
# Trainable params: 276,350
# Non-trainable params: 0
# _________________________________________________________________
# Train on 6399 samples, validate on 1600 samples
# Epoch 1/20
# 6399/6399 - 10s - loss: 0.1100 - val_loss: 0.1001
# Epoch 2/20
# 6399/6399 - 2s - loss: 0.1068 - val_loss: 0.0968
# Epoch 3/20
# 6399/6399 - 2s - loss: 0.1004 - val_loss: 0.0923
# Epoch 4/20
# 6399/6399 - 2s - loss: 0.0949 - val_loss: 0.0884
# Epoch 5/20
# 6399/6399 - 2s - loss: 0.0909 - val_loss: 0.0859
# Epoch 6/20
# 6399/6399 - 2s - loss: 0.0884 - val_loss: 0.0842
# Epoch 7/20
# 6399/6399 - 2s - loss: 0.0864 - val_loss: 0.0829
# Epoch 8/20
# 6399/6399 - 2s - loss: 0.0849 - val_loss: 0.0816
# Epoch 9/20
# 6399/6399 - 2s - loss: 0.0834 - val_loss: 0.0803
# Epoch 10/20
# 6399/6399 - 2s - loss: 0.0824 - val_loss: 0.0790
# Epoch 11/20
# 6399/6399 - 2s - loss: 0.0815 - val_loss: 0.0784
# Epoch 12/20
# 6399/6399 - 2s - loss: 0.0805 - val_loss: 0.0775
# Epoch 13/20
# 6399/6399 - 2s - loss: 0.0797 - val_loss: 0.0769
# Epoch 14/20
# 6399/6399 - 2s - loss: 0.0792 - val_loss: 0.0766
# Epoch 15/20
# 6399/6399 - 2s - loss: 0.0786 - val_loss: 0.0756
# Epoch 16/20
# 6399/6399 - 2s - loss: 0.0780 - val_loss: 0.0752
# Epoch 17/20
# 6399/6399 - 2s - loss: 0.0776 - val_loss: 0.0746
# Epoch 18/20
# 6399/6399 - 2s - loss: 0.0771 - val_loss: 0.0745
# Epoch 19/20
# 6399/6399 - 2s - loss: 0.0767 - val_loss: 0.0741
# Epoch 20/20
# 6399/6399 - 2s - loss: 0.0763 - val_loss: 0.0736
# Training length: 9000
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_39 (LSTM)               (None, 1, 100)            100400
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_40 (LSTM)               (None, 1, 100)            80400
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_41 (LSTM)               (None, 100)               80400
# _________________________________________________________________
# dense_13 (Dense)             (None, 150)               15150
# =================================================================
# Total params: 276,350
# Trainable params: 276,350
# Non-trainable params: 0
# _________________________________________________________________
# Train on 7199 samples, validate on 1800 samples
# Epoch 1/20
# 7199/7199 - 10s - loss: 0.1135 - val_loss: 0.1033
# Epoch 2/20
# 7199/7199 - 2s - loss: 0.1102 - val_loss: 0.0998
# Epoch 3/20
# 7199/7199 - 2s - loss: 0.1027 - val_loss: 0.0934
# Epoch 4/20
# 7199/7199 - 2s - loss: 0.0966 - val_loss: 0.0895
# Epoch 5/20
# 7199/7199 - 2s - loss: 0.0929 - val_loss: 0.0871
# Epoch 6/20
# 7199/7199 - 2s - loss: 0.0901 - val_loss: 0.0847
# Epoch 7/20
# 7199/7199 - 2s - loss: 0.0880 - val_loss: 0.0831
# Epoch 8/20
# 7199/7199 - 2s - loss: 0.0864 - val_loss: 0.0815
# Epoch 9/20
# 7199/7199 - 2s - loss: 0.0851 - val_loss: 0.0808
# Epoch 10/20
# 7199/7199 - 2s - loss: 0.0842 - val_loss: 0.0799
# Epoch 11/20
# 7199/7199 - 2s - loss: 0.0832 - val_loss: 0.0791
# Epoch 12/20
# 7199/7199 - 2s - loss: 0.0825 - val_loss: 0.0788
# Epoch 13/20
# 7199/7199 - 2s - loss: 0.0817 - val_loss: 0.0780
# Epoch 14/20
# 7199/7199 - 2s - loss: 0.0811 - val_loss: 0.0773
# Epoch 15/20
# 7199/7199 - 2s - loss: 0.0805 - val_loss: 0.0769
# Epoch 16/20
# 7199/7199 - 2s - loss: 0.0800 - val_loss: 0.0764
# Epoch 17/20
# 7199/7199 - 2s - loss: 0.0794 - val_loss: 0.0758
# Epoch 18/20
# 7199/7199 - 2s - loss: 0.0790 - val_loss: 0.0755
# Epoch 19/20
# 7199/7199 - 2s - loss: 0.0786 - val_loss: 0.0752
# Epoch 20/20
# 7199/7199 - 2s - loss: 0.0782 - val_loss: 0.0747
# Training length: 10000
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_42 (LSTM)               (None, 1, 100)            100400
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_43 (LSTM)               (None, 1, 100)            80400
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_44 (LSTM)               (None, 100)               80400
# _________________________________________________________________
# dense_14 (Dense)             (None, 150)               15150
# =================================================================
# Total params: 276,350
# Trainable params: 276,350
# Non-trainable params: 0
# _________________________________________________________________
# Train on 7999 samples, validate on 2000 samples
# Epoch 1/20
# 7999/7999 - 11s - loss: 0.1081 - val_loss: 0.1066
# Epoch 2/20
# 7999/7999 - 3s - loss: 0.1050 - val_loss: 0.1026
# Epoch 3/20
# 7999/7999 - 3s - loss: 0.0979 - val_loss: 0.0944
# Epoch 4/20
# 7999/7999 - 3s - loss: 0.0923 - val_loss: 0.0911
# Epoch 5/20
# 7999/7999 - 3s - loss: 0.0888 - val_loss: 0.0886
# Epoch 6/20
# 7999/7999 - 3s - loss: 0.0863 - val_loss: 0.0864
# Epoch 7/20
# 7999/7999 - 3s - loss: 0.0845 - val_loss: 0.0847
# Epoch 8/20
# 7999/7999 - 3s - loss: 0.0828 - val_loss: 0.0830
# Epoch 9/20
# 7999/7999 - 3s - loss: 0.0814 - val_loss: 0.0811
# Epoch 10/20
# 7999/7999 - 3s - loss: 0.0802 - val_loss: 0.0799
# Epoch 11/20
# 7999/7999 - 3s - loss: 0.0793 - val_loss: 0.0790
# Epoch 12/20
# 7999/7999 - 3s - loss: 0.0785 - val_loss: 0.0783
# Epoch 13/20
# 7999/7999 - 3s - loss: 0.0777 - val_loss: 0.0775
# Epoch 14/20
# 7999/7999 - 3s - loss: 0.0771 - val_loss: 0.0769
# Epoch 15/20
# 7999/7999 - 3s - loss: 0.0766 - val_loss: 0.0768
# Epoch 16/20
# 7999/7999 - 3s - loss: 0.0761 - val_loss: 0.0760
# Epoch 17/20
# 7999/7999 - 3s - loss: 0.0757 - val_loss: 0.0758
# Epoch 18/20
# 7999/7999 - 3s - loss: 0.0754 - val_loss: 0.0751
# Epoch 19/20
# 7999/7999 - 3s - loss: 0.0750 - val_loss: 0.0751
# Epoch 20/20
# 7999/7999 - 3s - loss: 0.0746 - val_loss: 0.0750
# Training length: 11000
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_45 (LSTM)               (None, 1, 100)            100400
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_46 (LSTM)               (None, 1, 100)            80400
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_47 (LSTM)               (None, 100)               80400
# _________________________________________________________________
# dense_15 (Dense)             (None, 150)               15150
# =================================================================
# Total params: 276,350
# Trainable params: 276,350
# Non-trainable params: 0
# _________________________________________________________________
# Train on 8799 samples, validate on 2200 samples
# Epoch 1/20
# 8799/8799 - 11s - loss: 0.1038 - val_loss: 0.1086
# Epoch 2/20
# 8799/8799 - 3s - loss: 0.0981 - val_loss: 0.0985
# Epoch 3/20
# 8799/8799 - 3s - loss: 0.0903 - val_loss: 0.0931
# Epoch 4/20
# 8799/8799 - 3s - loss: 0.0865 - val_loss: 0.0898
# Epoch 5/20
# 8799/8799 - 3s - loss: 0.0840 - val_loss: 0.0875
# Epoch 6/20
# 8799/8799 - 3s - loss: 0.0820 - val_loss: 0.0857
# Epoch 7/20
# 8799/8799 - 3s - loss: 0.0805 - val_loss: 0.0842
# Epoch 8/20
# 8799/8799 - 3s - loss: 0.0791 - val_loss: 0.0825
# Epoch 9/20
# 8799/8799 - 3s - loss: 0.0780 - val_loss: 0.0815
# Epoch 10/20
# 8799/8799 - 3s - loss: 0.0771 - val_loss: 0.0804
# Epoch 11/20
# 8799/8799 - 3s - loss: 0.0763 - val_loss: 0.0795
# Epoch 12/20
# 8799/8799 - 3s - loss: 0.0755 - val_loss: 0.0788
# Epoch 13/20
# 8799/8799 - 3s - loss: 0.0750 - val_loss: 0.0783
# Epoch 14/20
# 8799/8799 - 3s - loss: 0.0746 - val_loss: 0.0778
# Epoch 15/20
# 8799/8799 - 3s - loss: 0.0741 - val_loss: 0.0772
# Epoch 16/20
# 8799/8799 - 3s - loss: 0.0737 - val_loss: 0.0770
# Epoch 17/20
# 8799/8799 - 3s - loss: 0.0733 - val_loss: 0.0766
# Epoch 18/20
# 8799/8799 - 3s - loss: 0.0729 - val_loss: 0.0760
# Epoch 19/20
# 8799/8799 - 3s - loss: 0.0726 - val_loss: 0.0759
# Epoch 20/20
# 8799/8799 - 3s - loss: 0.0723 - val_loss: 0.0753
# Training length: 12000
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_48 (LSTM)               (None, 1, 100)            100400
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_49 (LSTM)               (None, 1, 100)            80400
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_50 (LSTM)               (None, 100)               80400
# _________________________________________________________________
# dense_16 (Dense)             (None, 150)               15150
# =================================================================
# Total params: 276,350
# Trainable params: 276,350
# Non-trainable params: 0
# _________________________________________________________________
# Train on 9599 samples, validate on 2400 samples
# Epoch 1/20
# 9599/9599 - 11s - loss: 0.1063 - val_loss: 0.1087
# Epoch 2/20
# 9599/9599 - 3s - loss: 0.0993 - val_loss: 0.0985
# Epoch 3/20
# 9599/9599 - 3s - loss: 0.0921 - val_loss: 0.0931
# Epoch 4/20
# 9599/9599 - 3s - loss: 0.0882 - val_loss: 0.0897
# Epoch 5/20
# 9599/9599 - 3s - loss: 0.0857 - val_loss: 0.0874
# Epoch 6/20
# 9599/9599 - 3s - loss: 0.0837 - val_loss: 0.0853
# Epoch 7/20
# 9599/9599 - 3s - loss: 0.0822 - val_loss: 0.0840
# Epoch 8/20
# 9599/9599 - 3s - loss: 0.0809 - val_loss: 0.0826
# Epoch 9/20
# 9599/9599 - 3s - loss: 0.0799 - val_loss: 0.0817
# Epoch 10/20
# 9599/9599 - 3s - loss: 0.0789 - val_loss: 0.0808
# Epoch 11/20
# 9599/9599 - 3s - loss: 0.0782 - val_loss: 0.0800
# Epoch 12/20
# 9599/9599 - 3s - loss: 0.0774 - val_loss: 0.0791
# Epoch 13/20
# 9599/9599 - 3s - loss: 0.0768 - val_loss: 0.0786
# Epoch 14/20
# 9599/9599 - 3s - loss: 0.0763 - val_loss: 0.0780
# Epoch 15/20
# 9599/9599 - 3s - loss: 0.0759 - val_loss: 0.0780
# Epoch 16/20
# 9599/9599 - 3s - loss: 0.0753 - val_loss: 0.0770
# Epoch 17/20
# 9599/9599 - 3s - loss: 0.0749 - val_loss: 0.0766
# Epoch 18/20
# 9599/9599 - 3s - loss: 0.0745 - val_loss: 0.0765
# Epoch 19/20
# 9599/9599 - 3s - loss: 0.0743 - val_loss: 0.0761
# Epoch 20/20
# 9599/9599 - 3s - loss: 0.0739 - val_loss: 0.0755
# Training length: 13000
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_51 (LSTM)               (None, 1, 100)            100400
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_52 (LSTM)               (None, 1, 100)            80400
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_53 (LSTM)               (None, 100)               80400
# _________________________________________________________________
# dense_17 (Dense)             (None, 150)               15150
# =================================================================
# Total params: 276,350
# Trainable params: 276,350
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10399 samples, validate on 2600 samples
# Epoch 1/20
# 10399/10399 - 12s - loss: 0.1067 - val_loss: 0.1007
# Epoch 2/20
# 10399/10399 - 3s - loss: 0.0978 - val_loss: 0.0928
# Epoch 3/20
# 10399/10399 - 3s - loss: 0.0904 - val_loss: 0.0872
# Epoch 4/20
# 10399/10399 - 3s - loss: 0.0870 - val_loss: 0.0853
# Epoch 5/20
# 10399/10399 - 3s - loss: 0.0846 - val_loss: 0.0813
# Epoch 6/20
# 10399/10399 - 3s - loss: 0.0828 - val_loss: 0.0795
# Epoch 7/20
# 10399/10399 - 3s - loss: 0.0813 - val_loss: 0.0778
# Epoch 8/20
# 10399/10399 - 3s - loss: 0.0801 - val_loss: 0.0773
# Epoch 9/20
# 10399/10399 - 3s - loss: 0.0792 - val_loss: 0.0759
# Epoch 10/20
# 10399/10399 - 3s - loss: 0.0783 - val_loss: 0.0751
# Epoch 11/20
# 10399/10399 - 3s - loss: 0.0776 - val_loss: 0.0747
# Epoch 12/20
# 10399/10399 - 3s - loss: 0.0770 - val_loss: 0.0734
# Epoch 13/20
# 10399/10399 - 3s - loss: 0.0765 - val_loss: 0.0736
# Epoch 14/20
# 10399/10399 - 3s - loss: 0.0760 - val_loss: 0.0727
# Epoch 15/20
# 10399/10399 - 3s - loss: 0.0756 - val_loss: 0.0729
# Epoch 16/20
# 10399/10399 - 3s - loss: 0.0751 - val_loss: 0.0715
# Epoch 17/20
# 10399/10399 - 3s - loss: 0.0747 - val_loss: 0.0712
# Epoch 18/20
# 10399/10399 - 3s - loss: 0.0746 - val_loss: 0.0714
# Epoch 19/20
# 10399/10399 - 3s - loss: 0.0742 - val_loss: 0.0708
# Epoch 20/20
# 10399/10399 - 3s - loss: 0.0739 - val_loss: 0.0710
# Training length: 14000
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_54 (LSTM)               (None, 1, 100)            100400
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_55 (LSTM)               (None, 1, 100)            80400
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_56 (LSTM)               (None, 100)               80400
# _________________________________________________________________
# dense_18 (Dense)             (None, 150)               15150
# =================================================================
# Total params: 276,350
# Trainable params: 276,350
# Non-trainable params: 0
# _________________________________________________________________
# Train on 11199 samples, validate on 2800 samples
# Epoch 1/20
# 11199/11199 - 12s - loss: 0.1060 - val_loss: 0.1012
# Epoch 2/20
# 11199/11199 - 4s - loss: 0.0963 - val_loss: 0.0909
# Epoch 3/20
# 11199/11199 - 4s - loss: 0.0897 - val_loss: 0.0877
# Epoch 4/20
# 11199/11199 - 4s - loss: 0.0867 - val_loss: 0.0843
# Epoch 5/20
# 11199/11199 - 4s - loss: 0.0844 - val_loss: 0.0817
# Epoch 6/20
# 11199/11199 - 4s - loss: 0.0828 - val_loss: 0.0801
# Epoch 7/20
# 11199/11199 - 4s - loss: 0.0815 - val_loss: 0.0788
# Epoch 8/20
# 11199/11199 - 4s - loss: 0.0803 - val_loss: 0.0775
# Epoch 9/20
# 11199/11199 - 4s - loss: 0.0795 - val_loss: 0.0766
# Epoch 10/20
# 11199/11199 - 4s - loss: 0.0786 - val_loss: 0.0756
# Epoch 11/20
# 11199/11199 - 4s - loss: 0.0780 - val_loss: 0.0753
# Epoch 12/20
# 11199/11199 - 4s - loss: 0.0774 - val_loss: 0.0745
# Epoch 13/20
# 11199/11199 - 4s - loss: 0.0769 - val_loss: 0.0737
# Epoch 14/20
# 11199/11199 - 4s - loss: 0.0762 - val_loss: 0.0733
# Epoch 15/20
# 11199/11199 - 4s - loss: 0.0758 - val_loss: 0.0732
# Epoch 16/20
# 11199/11199 - 4s - loss: 0.0754 - val_loss: 0.0724
# Epoch 17/20
# 11199/11199 - 4s - loss: 0.0751 - val_loss: 0.0720
# Epoch 18/20
# 11199/11199 - 4s - loss: 0.0747 - val_loss: 0.0714
# Epoch 19/20
# 11199/11199 - 4s - loss: 0.0743 - val_loss: 0.0716
# Epoch 20/20
# 11199/11199 - 4s - loss: 0.0741 - val_loss: 0.0707
# Training length: 15000
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_57 (LSTM)               (None, 1, 100)            100400
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_58 (LSTM)               (None, 1, 100)            80400
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_59 (LSTM)               (None, 100)               80400
# _________________________________________________________________
# dense_19 (Dense)             (None, 150)               15150
# =================================================================
# Total params: 276,350
# Trainable params: 276,350
# Non-trainable params: 0
# _________________________________________________________________
# Train on 11999 samples, validate on 3000 samples
# Epoch 1/20
# 11999/11999 - 12s - loss: 0.1051 - val_loss: 0.0972
# Epoch 2/20
# 11999/11999 - 4s - loss: 0.0950 - val_loss: 0.0898
# Epoch 3/20
# 11999/11999 - 4s - loss: 0.0902 - val_loss: 0.0867
# Epoch 4/20
# 11999/11999 - 4s - loss: 0.0875 - val_loss: 0.0843
# Epoch 5/20
# 11999/11999 - 4s - loss: 0.0853 - val_loss: 0.0820
# Epoch 6/20
# 11999/11999 - 4s - loss: 0.0837 - val_loss: 0.0807
# Epoch 7/20
# 11999/11999 - 4s - loss: 0.0824 - val_loss: 0.0789
# Epoch 8/20
# 11999/11999 - 4s - loss: 0.0812 - val_loss: 0.0780
# Epoch 9/20
# 11999/11999 - 4s - loss: 0.0801 - val_loss: 0.0767
# Epoch 10/20
# 11999/11999 - 4s - loss: 0.0793 - val_loss: 0.0757
# Epoch 11/20
# 11999/11999 - 4s - loss: 0.0787 - val_loss: 0.0751
# Epoch 12/20
# 11999/11999 - 4s - loss: 0.0780 - val_loss: 0.0748
# Epoch 13/20
# 11999/11999 - 4s - loss: 0.0775 - val_loss: 0.0739
# Epoch 14/20
# 11999/11999 - 4s - loss: 0.0770 - val_loss: 0.0731
# Epoch 15/20
# 11999/11999 - 4s - loss: 0.0764 - val_loss: 0.0728
# Epoch 16/20
# 11999/11999 - 4s - loss: 0.0761 - val_loss: 0.0721
# Epoch 17/20
# 11999/11999 - 4s - loss: 0.0757 - val_loss: 0.0723
# Epoch 18/20
# 11999/11999 - 4s - loss: 0.0754 - val_loss: 0.0719
# Epoch 19/20
# 11999/11999 - 4s - loss: 0.0750 - val_loss: 0.0711
# Epoch 20/20
# 11999/11999 - 4s - loss: 0.0747 - val_loss: 0.0711
# Training length: 16000
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_60 (LSTM)               (None, 1, 100)            100400
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_61 (LSTM)               (None, 1, 100)            80400
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_62 (LSTM)               (None, 100)               80400
# _________________________________________________________________
# dense_20 (Dense)             (None, 150)               15150
# =================================================================
# Total params: 276,350
# Trainable params: 276,350
# Non-trainable params: 0
# _________________________________________________________________
# Train on 12799 samples, validate on 3200 samples
# Epoch 1/20
# 12799/12799 - 11s - loss: 0.1070 - val_loss: 0.0990
# Epoch 2/20
# 12799/12799 - 4s - loss: 0.0963 - val_loss: 0.0905
# Epoch 3/20
# 12799/12799 - 4s - loss: 0.0908 - val_loss: 0.0870
# Epoch 4/20
# 12799/12799 - 4s - loss: 0.0878 - val_loss: 0.0834
# Epoch 5/20
# 12799/12799 - 4s - loss: 0.0854 - val_loss: 0.0818
# Epoch 6/20
# 12799/12799 - 4s - loss: 0.0837 - val_loss: 0.0798
# Epoch 7/20
# 12799/12799 - 4s - loss: 0.0823 - val_loss: 0.0784
# Epoch 8/20
# 12799/12799 - 4s - loss: 0.0811 - val_loss: 0.0771
# Epoch 9/20
# 12799/12799 - 4s - loss: 0.0802 - val_loss: 0.0764
# Epoch 10/20
# 12799/12799 - 4s - loss: 0.0794 - val_loss: 0.0754
# Epoch 11/20
# 12799/12799 - 4s - loss: 0.0787 - val_loss: 0.0747
# Epoch 12/20
# 12799/12799 - 4s - loss: 0.0781 - val_loss: 0.0738
# Epoch 13/20
# 12799/12799 - 4s - loss: 0.0775 - val_loss: 0.0731
# Epoch 14/20
# 12799/12799 - 4s - loss: 0.0770 - val_loss: 0.0727
# Epoch 15/20
# 12799/12799 - 4s - loss: 0.0765 - val_loss: 0.0726
# Epoch 16/20
# 12799/12799 - 4s - loss: 0.0761 - val_loss: 0.0719
# Epoch 17/20
# 12799/12799 - 4s - loss: 0.0759 - val_loss: 0.0717
# Epoch 18/20
# 12799/12799 - 4s - loss: 0.0756 - val_loss: 0.0713
# Epoch 19/20
# 12799/12799 - 4s - loss: 0.0752 - val_loss: 0.0709
# Epoch 20/20
# 12799/12799 - 4s - loss: 0.0749 - val_loss: 0.0707
# Training length: 17000
# Model: "sequential_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_63 (LSTM)               (None, 1, 100)            100400
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_64 (LSTM)               (None, 1, 100)            80400
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_65 (LSTM)               (None, 100)               80400
# _________________________________________________________________
# dense_21 (Dense)             (None, 150)               15150
# =================================================================
# Total params: 276,350
# Trainable params: 276,350
# Non-trainable params: 0
# _________________________________________________________________
# Train on 13599 samples, validate on 3400 samples
# Epoch 1/20
# 13599/13599 - 12s - loss: 0.1083 - val_loss: 0.1002
# Epoch 2/20
# 13599/13599 - 4s - loss: 0.0974 - val_loss: 0.0902
# Epoch 3/20
# 13599/13599 - 4s - loss: 0.0906 - val_loss: 0.0855
# Epoch 4/20
# 13599/13599 - 4s - loss: 0.0870 - val_loss: 0.0821
# Epoch 5/20
# 13599/13599 - 4s - loss: 0.0848 - val_loss: 0.0803
# Epoch 6/20
# 13599/13599 - 4s - loss: 0.0832 - val_loss: 0.0787
# Epoch 7/20
# 13599/13599 - 4s - loss: 0.0821 - val_loss: 0.0774
# Epoch 8/20
# 13599/13599 - 4s - loss: 0.0810 - val_loss: 0.0763
# Epoch 9/20
# 13599/13599 - 4s - loss: 0.0801 - val_loss: 0.0753
# Epoch 10/20
# 13599/13599 - 4s - loss: 0.0793 - val_loss: 0.0745
# Epoch 11/20
# 13599/13599 - 4s - loss: 0.0787 - val_loss: 0.0738
# Epoch 12/20
# 13599/13599 - 4s - loss: 0.0782 - val_loss: 0.0732
# Epoch 13/20
# 13599/13599 - 4s - loss: 0.0776 - val_loss: 0.0724
# Epoch 14/20
# 13599/13599 - 4s - loss: 0.0772 - val_loss: 0.0720
# Epoch 15/20
# 13599/13599 - 4s - loss: 0.0768 - val_loss: 0.0717
# Epoch 16/20
# 13599/13599 - 4s - loss: 0.0764 - val_loss: 0.0711
# Epoch 17/20
# 13599/13599 - 4s - loss: 0.0761 - val_loss: 0.0708
# Epoch 18/20
# 13599/13599 - 4s - loss: 0.0757 - val_loss: 0.0705
# Epoch 19/20
# 13599/13599 - 4s - loss: 0.0755 - val_loss: 0.0705
# Epoch 20/20
# 13599/13599 - 4s - loss: 0.0753 - val_loss: 0.0699
# Training length: 18000
# Model: "sequential_22"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_66 (LSTM)               (None, 1, 100)            100400
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_67 (LSTM)               (None, 1, 100)            80400
# _________________________________________________________________
# dropout_45 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_68 (LSTM)               (None, 100)               80400
# _________________________________________________________________
# dense_22 (Dense)             (None, 150)               15150
# =================================================================
# Total params: 276,350
# Trainable params: 276,350
# Non-trainable params: 0
# _________________________________________________________________
# Train on 14399 samples, validate on 3600 samples
# Epoch 1/20
# 14399/14399 - 12s - loss: 0.1096 - val_loss: 0.1029
# Epoch 2/20
# 14399/14399 - 5s - loss: 0.1003 - val_loss: 0.0928
# Epoch 3/20
# 14399/14399 - 5s - loss: 0.0925 - val_loss: 0.0882
# Epoch 4/20
# 14399/14399 - 5s - loss: 0.0886 - val_loss: 0.0842
# Epoch 5/20
# 14399/14399 - 4s - loss: 0.0860 - val_loss: 0.0820
# Epoch 6/20
# 14399/14399 - 4s - loss: 0.0842 - val_loss: 0.0799
# Epoch 7/20
# 14399/14399 - 4s - loss: 0.0829 - val_loss: 0.0784
# Epoch 8/20
# 14399/14399 - 5s - loss: 0.0818 - val_loss: 0.0773
# Epoch 9/20
# 14399/14399 - 4s - loss: 0.0807 - val_loss: 0.0759
# Epoch 10/20
# 14399/14399 - 4s - loss: 0.0798 - val_loss: 0.0755
# Epoch 11/20
# 14399/14399 - 4s - loss: 0.0791 - val_loss: 0.0744
# Epoch 12/20
# 14399/14399 - 4s - loss: 0.0785 - val_loss: 0.0735
# Epoch 13/20
# 14399/14399 - 4s - loss: 0.0780 - val_loss: 0.0730
# Epoch 14/20
# 14399/14399 - 4s - loss: 0.0775 - val_loss: 0.0726
# Epoch 15/20
# 14399/14399 - 4s - loss: 0.0771 - val_loss: 0.0718
# Epoch 16/20
# 14399/14399 - 4s - loss: 0.0767 - val_loss: 0.0717
# Epoch 17/20
# 14399/14399 - 4s - loss: 0.0764 - val_loss: 0.0712
# Epoch 18/20
# 14399/14399 - 4s - loss: 0.0761 - val_loss: 0.0709
# Epoch 19/20
# 14399/14399 - 4s - loss: 0.0758 - val_loss: 0.0702
# Epoch 20/20
# 14399/14399 - 4s - loss: 0.0756 - val_loss: 0.0703
# Training length: 19000
# Model: "sequential_23"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_69 (LSTM)               (None, 1, 100)            100400
# _________________________________________________________________
# dropout_46 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_70 (LSTM)               (None, 1, 100)            80400
# _________________________________________________________________
# dropout_47 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_71 (LSTM)               (None, 100)               80400
# _________________________________________________________________
# dense_23 (Dense)             (None, 150)               15150
# =================================================================
# Total params: 276,350
# Trainable params: 276,350
# Non-trainable params: 0
# _________________________________________________________________
# Train on 15199 samples, validate on 3800 samples
# Epoch 1/20
# 15199/15199 - 13s - loss: 0.1106 - val_loss: 0.1038
# Epoch 2/20
# 15199/15199 - 5s - loss: 0.0998 - val_loss: 0.0919
# Epoch 3/20
# 15199/15199 - 5s - loss: 0.0927 - val_loss: 0.0875
# Epoch 4/20
# 15199/15199 - 5s - loss: 0.0889 - val_loss: 0.0845
# Epoch 5/20
# 15199/15199 - 5s - loss: 0.0865 - val_loss: 0.0822
# Epoch 6/20
# 15199/15199 - 5s - loss: 0.0847 - val_loss: 0.0801
# Epoch 7/20
# 15199/15199 - 5s - loss: 0.0833 - val_loss: 0.0789
# Epoch 8/20
# 15199/15199 - 5s - loss: 0.0823 - val_loss: 0.0774
# Epoch 9/20
# 15199/15199 - 5s - loss: 0.0815 - val_loss: 0.0764
# Epoch 10/20
# 15199/15199 - 5s - loss: 0.0807 - val_loss: 0.0758
# Epoch 11/20
# 15199/15199 - 5s - loss: 0.0801 - val_loss: 0.0747
# Epoch 12/20
# 15199/15199 - 5s - loss: 0.0795 - val_loss: 0.0742
# Epoch 13/20
# 15199/15199 - 5s - loss: 0.0790 - val_loss: 0.0735
# Epoch 14/20
# 15199/15199 - 5s - loss: 0.0785 - val_loss: 0.0731
# Epoch 15/20
# 15199/15199 - 5s - loss: 0.0782 - val_loss: 0.0724
# Epoch 16/20
# 15199/15199 - 5s - loss: 0.0778 - val_loss: 0.0721
# Epoch 17/20
# 15199/15199 - 5s - loss: 0.0775 - val_loss: 0.0716
# Epoch 18/20
# 15199/15199 - 5s - loss: 0.0772 - val_loss: 0.0715
# Epoch 19/20
# 15199/15199 - 5s - loss: 0.0770 - val_loss: 0.0712
# Epoch 20/20
# 15199/15199 - 5s - loss: 0.0767 - val_loss: 0.0710
# Training length: 20000
# Model: "sequential_24"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_72 (LSTM)               (None, 1, 100)            100400
# _________________________________________________________________
# dropout_48 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_73 (LSTM)               (None, 1, 100)            80400
# _________________________________________________________________
# dropout_49 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_74 (LSTM)               (None, 100)               80400
# _________________________________________________________________
# dense_24 (Dense)             (None, 150)               15150
# =================================================================
# Total params: 276,350
# Trainable params: 276,350
# Non-trainable params: 0
# _________________________________________________________________
# Train on 15999 samples, validate on 4000 samples
# Epoch 1/20
# 15999/15999 - 13s - loss: 0.1116 - val_loss: 0.1011
# Epoch 2/20
# 15999/15999 - 5s - loss: 0.0998 - val_loss: 0.0911
# Epoch 3/20
# 15999/15999 - 5s - loss: 0.0932 - val_loss: 0.0867
# Epoch 4/20
# 15999/15999 - 5s - loss: 0.0896 - val_loss: 0.0832
# Epoch 5/20
# ...
# Epoch 4/20
# 27199/27199 - 9s - loss: 0.0851 - val_loss: 0.0811
# Epoch 5/20
# 27199/27199 - 9s - loss: 0.0833 - val_loss: 0.0789
# Epoch 6/20
# 27199/27199 - 9s - loss: 0.0820 - val_loss: 0.0772
# Epoch 7/20
# 27199/27199 - 9s - loss: 0.0809 - val_loss: 0.0759
# Epoch 8/20
# 27199/27199 - 9s - loss: 0.0802 - val_loss: 0.0751
# Epoch 9/20
# 27199/27199 - 9s - loss: 0.0797 - val_loss: 0.0742
# Epoch 10/20
# 27199/27199 - 9s - loss: 0.0793 - val_loss: 0.0737
# Epoch 11/20
# 27199/27199 - 9s - loss: 0.0788 - val_loss: 0.0732
# Epoch 12/20
# 27199/27199 - 9s - loss: 0.0785 - val_loss: 0.0726
# Epoch 13/20
# 27199/27199 - 9s - loss: 0.0782 - val_loss: 0.0722
# Epoch 14/20
# 27199/27199 - 9s - loss: 0.0778 - val_loss: 0.0721
# Epoch 15/20
# 27199/27199 - 9s - loss: 0.0776 - val_loss: 0.0714
# Epoch 16/20
# 27199/27199 - 9s - loss: 0.0773 - val_loss: 0.0710
# Epoch 17/20
# 27199/27199 - 9s - loss: 0.0770 - val_loss: 0.0707
# Epoch 18/20
# 27199/27199 - 9s - loss: 0.0768 - val_loss: 0.0704
# Epoch 19/20
# 27199/27199 - 9s - loss: 0.0766 - val_loss: 0.0701
# Epoch 20/20
# 27199/27199 - 9s - loss: 0.0765 - val_loss: 0.0699
# Training length: 35000
# Model: "sequential_39"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_117 (LSTM)              (None, 1, 100)            100400
# _________________________________________________________________
# dropout_78 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_118 (LSTM)              (None, 1, 100)            80400
# _________________________________________________________________
# dropout_79 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_119 (LSTM)              (None, 100)               80400
# _________________________________________________________________
# dense_39 (Dense)             (None, 150)               15150
# =================================================================
# Total params: 276,350
# Trainable params: 276,350
# Non-trainable params: 0
# _________________________________________________________________
# Train on 27999 samples, validate on 7000 samples
# Epoch 1/20
# 27999/27999 - 17s - loss: 0.1000 - val_loss: 0.0949
# Epoch 2/20
# 27999/27999 - 9s - loss: 0.0888 - val_loss: 0.0871
# Epoch 3/20
# 27999/27999 - 9s - loss: 0.0842 - val_loss: 0.0823
# Epoch 4/20
# 27999/27999 - 9s - loss: 0.0817 - val_loss: 0.0795
# Epoch 5/20
# 27999/27999 - 9s - loss: 0.0802 - val_loss: 0.0776
# Epoch 6/20
# 27999/27999 - 9s - loss: 0.0790 - val_loss: 0.0762
# Epoch 7/20
# 27999/27999 - 9s - loss: 0.0781 - val_loss: 0.0750
# Epoch 8/20
# 27999/27999 - 9s - loss: 0.0773 - val_loss: 0.0740
# Epoch 9/20
# 27999/27999 - 9s - loss: 0.0767 - val_loss: 0.0729
# Epoch 10/20
# 27999/27999 - 9s - loss: 0.0762 - val_loss: 0.0724
# Epoch 11/20
# 27999/27999 - 9s - loss: 0.0759 - val_loss: 0.0719
# Epoch 12/20
# 27999/27999 - 9s - loss: 0.0755 - val_loss: 0.0714
# Epoch 13/20
# 27999/27999 - 9s - loss: 0.0752 - val_loss: 0.0712
# Epoch 14/20
# 27999/27999 - 9s - loss: 0.0749 - val_loss: 0.0709
# Epoch 15/20
# 27999/27999 - 9s - loss: 0.0747 - val_loss: 0.0702
# Epoch 16/20
# 27999/27999 - 9s - loss: 0.0745 - val_loss: 0.0701
# Epoch 17/20
# 27999/27999 - 9s - loss: 0.0743 - val_loss: 0.0698
# Epoch 18/20
# 27999/27999 - 9s - loss: 0.0741 - val_loss: 0.0695
# Epoch 19/20
# 27999/27999 - 9s - loss: 0.0739 - val_loss: 0.0692
# Epoch 20/20
# 27999/27999 - 9s - loss: 0.0737 - val_loss: 0.0690
# Training length: 36000
# Model: "sequential_40"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_120 (LSTM)              (None, 1, 100)            100400
# _________________________________________________________________
# dropout_80 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_121 (LSTM)              (None, 1, 100)            80400
# _________________________________________________________________
# dropout_81 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_122 (LSTM)              (None, 100)               80400
# _________________________________________________________________
# dense_40 (Dense)             (None, 150)               15150
# =================================================================
# Total params: 276,350
# Trainable params: 276,350
# Non-trainable params: 0
# _________________________________________________________________
# Train on 28799 samples, validate on 7200 samples
# Epoch 1/20
# 28799/28799 - 17s - loss: 0.0977 - val_loss: 0.0932
# Epoch 2/20
# 28799/28799 - 9s - loss: 0.0865 - val_loss: 0.0864
# Epoch 3/20
# 28799/28799 - 9s - loss: 0.0829 - val_loss: 0.0822
# Epoch 4/20
# 28799/28799 - 9s - loss: 0.0804 - val_loss: 0.0792
# Epoch 5/20
# 28799/28799 - 9s - loss: 0.0788 - val_loss: 0.0773
# Epoch 6/20
# 28799/28799 - 9s - loss: 0.0777 - val_loss: 0.0757
# Epoch 7/20
# 28799/28799 - 9s - loss: 0.0769 - val_loss: 0.0746
# Epoch 8/20
# 28799/28799 - 9s - loss: 0.0763 - val_loss: 0.0736
# Epoch 9/20
# 28799/28799 - 9s - loss: 0.0757 - val_loss: 0.0727
# Epoch 10/20
# 28799/28799 - 9s - loss: 0.0752 - val_loss: 0.0720
# Epoch 11/20
# 28799/28799 - 9s - loss: 0.0748 - val_loss: 0.0715
# Epoch 12/20
# 28799/28799 - 9s - loss: 0.0745 - val_loss: 0.0711
# Epoch 13/20
# 28799/28799 - 9s - loss: 0.0742 - val_loss: 0.0707
# Epoch 14/20
# 28799/28799 - 9s - loss: 0.0739 - val_loss: 0.0704
# Epoch 15/20
# 28799/28799 - 9s - loss: 0.0737 - val_loss: 0.0698
# Epoch 16/20
# 28799/28799 - 9s - loss: 0.0734 - val_loss: 0.0696
# Epoch 17/20
# 28799/28799 - 9s - loss: 0.0733 - val_loss: 0.0693
# Epoch 18/20
# 28799/28799 - 9s - loss: 0.0730 - val_loss: 0.0691
# Epoch 19/20
# 28799/28799 - 9s - loss: 0.0730 - val_loss: 0.0688
# Epoch 20/20
# 28799/28799 - 9s - loss: 0.0728 - val_loss: 0.0686
# Training length: 37000
# Model: "sequential_41"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_123 (LSTM)              (None, 1, 100)            100400
# _________________________________________________________________
# dropout_82 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_124 (LSTM)              (None, 1, 100)            80400
# _________________________________________________________________
# dropout_83 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_125 (LSTM)              (None, 100)               80400
# _________________________________________________________________
# dense_41 (Dense)             (None, 150)               15150
# =================================================================
# Total params: 276,350
# Trainable params: 276,350
# Non-trainable params: 0
# _________________________________________________________________
# Train on 29599 samples, validate on 7400 samples
# Epoch 1/20
# 29599/29599 - 18s - loss: 0.0975 - val_loss: 0.0944
# Epoch 2/20
# 29599/29599 - 9s - loss: 0.0873 - val_loss: 0.0876
# Epoch 3/20
# 29599/29599 - 9s - loss: 0.0832 - val_loss: 0.0829
# Epoch 4/20
# 29599/29599 - 9s - loss: 0.0807 - val_loss: 0.0801
# Epoch 5/20
# 29599/29599 - 9s - loss: 0.0790 - val_loss: 0.0779
# Epoch 6/20
# 29599/29599 - 9s - loss: 0.0778 - val_loss: 0.0761
# Epoch 7/20
# 29599/29599 - 9s - loss: 0.0769 - val_loss: 0.0751
# Epoch 8/20
# 29599/29599 - 9s - loss: 0.0761 - val_loss: 0.0737
# Epoch 9/20
# 29599/29599 - 9s - loss: 0.0755 - val_loss: 0.0728
# Epoch 10/20
# 29599/29599 - 9s - loss: 0.0751 - val_loss: 0.0719
# Epoch 11/20
# 29599/29599 - 9s - loss: 0.0746 - val_loss: 0.0716
# Epoch 12/20
# 29599/29599 - 9s - loss: 0.0743 - val_loss: 0.0711
# Epoch 13/20
# 29599/29599 - 9s - loss: 0.0740 - val_loss: 0.0705
# Epoch 14/20
# 29599/29599 - 9s - loss: 0.0738 - val_loss: 0.0703
# Epoch 15/20
# 29599/29599 - 9s - loss: 0.0735 - val_loss: 0.0699
# Epoch 16/20
# 29599/29599 - 9s - loss: 0.0733 - val_loss: 0.0696
# Epoch 17/20
# 29599/29599 - 9s - loss: 0.0732 - val_loss: 0.0693
# Epoch 18/20
# 29599/29599 - 9s - loss: 0.0729 - val_loss: 0.0690
# Epoch 19/20
# 29599/29599 - 9s - loss: 0.0728 - val_loss: 0.0687
# Epoch 20/20
# 29599/29599 - 9s - loss: 0.0726 - val_loss: 0.0686
# Training length: 38000
# Model: "sequential_42"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_126 (LSTM)              (None, 1, 100)            100400
# _________________________________________________________________
# dropout_84 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_127 (LSTM)              (None, 1, 100)            80400
# _________________________________________________________________
# dropout_85 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_128 (LSTM)              (None, 100)               80400
# _________________________________________________________________
# dense_42 (Dense)             (None, 150)               15150
# =================================================================
# Total params: 276,350
# Trainable params: 276,350
# Non-trainable params: 0
# _________________________________________________________________
# Train on 30399 samples, validate on 7600 samples
# Epoch 1/20
# 30399/30399 - 17s - loss: 0.0974 - val_loss: 0.0944
# Epoch 2/20
# 30399/30399 - 10s - loss: 0.0870 - val_loss: 0.0867
# Epoch 3/20
# 30399/30399 - 10s - loss: 0.0829 - val_loss: 0.0821
# Epoch 4/20
# 30399/30399 - 10s - loss: 0.0805 - val_loss: 0.0794
# Epoch 5/20
# 30399/30399 - 10s - loss: 0.0789 - val_loss: 0.0773
# Epoch 6/20
# 30399/30399 - 10s - loss: 0.0778 - val_loss: 0.0758
# Epoch 7/20
# 30399/30399 - 10s - loss: 0.0769 - val_loss: 0.0743
# Epoch 8/20
# 30399/30399 - 10s - loss: 0.0762 - val_loss: 0.0734
# Epoch 9/20
# 30399/30399 - 10s - loss: 0.0756 - val_loss: 0.0725
# Epoch 10/20
# 30399/30399 - 10s - loss: 0.0752 - val_loss: 0.0719
# Epoch 11/20
# 30399/30399 - 10s - loss: 0.0748 - val_loss: 0.0716
# Epoch 12/20
# 30399/30399 - 10s - loss: 0.0746 - val_loss: 0.0710
# Epoch 13/20
# 30399/30399 - 10s - loss: 0.0743 - val_loss: 0.0706
# Epoch 14/20
# 30399/30399 - 10s - loss: 0.0740 - val_loss: 0.0703
# Epoch 15/20
# 30399/30399 - 10s - loss: 0.0739 - val_loss: 0.0701
# Epoch 16/20
# 30399/30399 - 10s - loss: 0.0736 - val_loss: 0.0698
# Epoch 17/20
# 30399/30399 - 10s - loss: 0.0733 - val_loss: 0.0695
# Epoch 18/20
# 30399/30399 - 10s - loss: 0.0733 - val_loss: 0.0691
# Epoch 19/20
# 30399/30399 - 10s - loss: 0.0731 - val_loss: 0.0690
# Epoch 20/20
# 30399/30399 - 10s - loss: 0.0729 - val_loss: 0.0688
# Training length: 39000
# Model: "sequential_43"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_129 (LSTM)              (None, 1, 100)            100400
# _________________________________________________________________
# dropout_86 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_130 (LSTM)              (None, 1, 100)            80400
# _________________________________________________________________
# dropout_87 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_131 (LSTM)              (None, 100)               80400
# _________________________________________________________________
# dense_43 (Dense)             (None, 150)               15150
# =================================================================
# Total params: 276,350
# Trainable params: 276,350
# Non-trainable params: 0
# _________________________________________________________________
# Train on 31199 samples, validate on 7800 samples
# Epoch 1/20
# 31199/31199 - 18s - loss: 0.0977 - val_loss: 0.0941
# Epoch 2/20
# 31199/31199 - 10s - loss: 0.0869 - val_loss: 0.0863
# Epoch 3/20
# 31199/31199 - 10s - loss: 0.0827 - val_loss: 0.0814
# Epoch 4/20
# 31199/31199 - 10s - loss: 0.0804 - val_loss: 0.0788
# Epoch 5/20
# 31199/31199 - 10s - loss: 0.0789 - val_loss: 0.0767
# Epoch 6/20
# 31199/31199 - 11s - loss: 0.0778 - val_loss: 0.0751
# Epoch 7/20
# 31199/31199 - 11s - loss: 0.0769 - val_loss: 0.0738
# Epoch 8/20
# 31199/31199 - 10s - loss: 0.0763 - val_loss: 0.0732
# Epoch 9/20
# 31199/31199 - 10s - loss: 0.0757 - val_loss: 0.0723
# Epoch 10/20
# 31199/31199 - 10s - loss: 0.0753 - val_loss: 0.0720
# Epoch 11/20
# 31199/31199 - 10s - loss: 0.0749 - val_loss: 0.0712
# Epoch 12/20
# 31199/31199 - 10s - loss: 0.0746 - val_loss: 0.0708
# Epoch 13/20
# 31199/31199 - 10s - loss: 0.0743 - val_loss: 0.0704
# Epoch 14/20
# 31199/31199 - 10s - loss: 0.0741 - val_loss: 0.0698
# Epoch 15/20
# 31199/31199 - 10s - loss: 0.0739 - val_loss: 0.0696
# Epoch 16/20
# 31199/31199 - 10s - loss: 0.0737 - val_loss: 0.0693
# Epoch 17/20
# 31199/31199 - 10s - loss: 0.0735 - val_loss: 0.0690
# Epoch 18/20
# 31199/31199 - 10s - loss: 0.0733 - val_loss: 0.0688
# Epoch 19/20
# 31199/31199 - 10s - loss: 0.0731 - val_loss: 0.0687
# Epoch 20/20
# 31199/31199 - 10s - loss: 0.0729 - val_loss: 0.0685
# Training length: 40000
# Model: "sequential_44"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_132 (LSTM)              (None, 1, 100)            100400
# _________________________________________________________________
# dropout_88 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_133 (LSTM)              (None, 1, 100)            80400
# _________________________________________________________________
# dropout_89 (Dropout)         (None, 1, 100)            0
# _________________________________________________________________
# lstm_134 (LSTM)              (None, 100)               80400
# _________________________________________________________________
# dense_44 (Dense)             (None, 150)               15150
# =================================================================
# Total params: 276,350
# Trainable params: 276,350
# Non-trainable params: 0
# _________________________________________________________________
# Train on 31999 samples, validate on 8000 samples
# Epoch 1/20
# 31999/31999 - 19s - loss: 0.0977 - val_loss: 0.0936
# Epoch 2/20
# 31999/31999 - 10s - loss: 0.0865 - val_loss: 0.0859
# Epoch 3/20
# 31999/31999 - 10s - loss: 0.0827 - val_loss: 0.0815
# Epoch 4/20
# 31999/31999 - 10s - loss: 0.0803 - val_loss: 0.0786
# Epoch 5/20
# 31999/31999 - 10s - loss: 0.0788 - val_loss: 0.0768
# Epoch 6/20
# 31999/31999 - 10s - loss: 0.0777 - val_loss: 0.0752
# Epoch 7/20
# 31999/31999 - 10s - loss: 0.0769 - val_loss: 0.0740
# Epoch 8/20
# 31999/31999 - 10s - loss: 0.0763 - val_loss: 0.0732
# Epoch 9/20
# 31999/31999 - 10s - loss: 0.0758 - val_loss: 0.0721
# Epoch 10/20
# 31999/31999 - 10s - loss: 0.0754 - val_loss: 0.0717
# Epoch 11/20
# 31999/31999 - 10s - loss: 0.0750 - val_loss: 0.0713
# Epoch 12/20
# 31999/31999 - 10s - loss: 0.0747 - val_loss: 0.0707
# Epoch 13/20
# 31999/31999 - 10s - loss: 0.0744 - val_loss: 0.0704
# Epoch 14/20
# 31999/31999 - 10s - loss: 0.0742 - val_loss: 0.0700
# Epoch 15/20
# 31999/31999 - 10s - loss: 0.0740 - val_loss: 0.0697
# Epoch 16/20
# 31999/31999 - 10s - loss: 0.0737 - val_loss: 0.0691
# Epoch 17/20
# 31999/31999 - 10s - loss: 0.0736 - val_loss: 0.0692
# Epoch 18/20
# 31999/31999 - 10s - loss: 0.0734 - val_loss: 0.0690
# Epoch 19/20
# 31999/31999 - 10s - loss: 0.0733 - val_loss: 0.0686
# Epoch 20/20
# 31999/31999 - 10s - loss: 0.0732 - val_loss: 0.0688

# %%
# Analyze RMSE on the test dataset for each training length
#for i in range(n_pc):
#    plt.scatter(n_train, rmse_test[:,i], color='b', alpha=0.1)
plt.plot(n_train, np.mean(rmse_test, axis=1),'r--', linewidth=2)
plt.xlabel('Training length')
plt.ylabel('RMSE')
plt.xlim([0, 40000])
plt.grid()
plt.savefig('LSTM_RMSE_sensitivity_to_training_length_150PCs.png')
plt.show()
np.save('LSTM_RMSE_sensitivity_to_training_length_150PCs',rmse_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-b0c489e73cdb> in <module>
#       9 plt.savefig('LSTM_RMSE_sensitivity_to_training_length_150PCs.png')
#      10 plt.show()
# ---> 11 np.save('LSTM_RMSE_sensitivity_to_training_length_150PCs',rmse_test, axis=1)
#
# <__array_function__ internals> in save(*args, **kwargs)
#
# TypeError: _save_dispatcher() got an unexpected keyword argument 'axis'

# %%
n_train = n_maxtrain
x_train, y_train, scaler = trainingdata(pcs, n_pc, n_train, 'standard_top_pc')

# %%
# %matplotlib inline
# Train the LSTM
start = datetime.now()
hyperparams = {'numhidunits':100, 'loss':'mae', 
               'optimizer':'adam', 'epochs':200,
               'numhidlayer':2, 'activation':'tanh',
               'isdrop':True, 'dropmag':0.2, 
               'validation_split':0.2}

model, history = fitLSTM(x_train, y_train, n_pc, **hyperparams)

print('Training time:',datetime.now()-start)

# plot history
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Test')
plt.legend()
plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 1, 100)            100400
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 100)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 1, 100)            80400
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 100)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 100)               80400
# _________________________________________________________________
# dense (Dense)                (None, 150)               15150
# =================================================================
# Total params: 276,350
# Trainable params: 276,350
# Non-trainable params: 0
# _________________________________________________________________
# Train on 31999 samples, validate on 8000 samples
# Epoch 1/50
# 31999/31999 - 17s - loss: 0.0976 - val_loss: 0.0937
# Epoch 2/50
# 31999/31999 - 9s - loss: 0.0869 - val_loss: 0.0868
# Epoch 3/50
# 31999/31999 - 9s - loss: 0.0833 - val_loss: 0.0826
# Epoch 4/50
# 31999/31999 - 9s - loss: 0.0811 - val_loss: 0.0798
# Epoch 5/50
# 31999/31999 - 9s - loss: 0.0793 - val_loss: 0.0773
# Epoch 6/50
# 31999/31999 - 9s - loss: 0.0780 - val_loss: 0.0754
# Epoch 7/50
# 31999/31999 - 9s - loss: 0.0769 - val_loss: 0.0739
# Epoch 8/50
# 31999/31999 - 9s - loss: 0.0763 - val_loss: 0.0732
# Epoch 9/50
# 31999/31999 - 9s - loss: 0.0758 - val_loss: 0.0726
# Epoch 10/50
# 31999/31999 - 9s - loss: 0.0754 - val_loss: 0.0718
# Epoch 11/50
# 31999/31999 - 9s - loss: 0.0751 - val_loss: 0.0714
# Epoch 12/50
# 31999/31999 - 9s - loss: 0.0747 - val_loss: 0.0708
# Epoch 13/50
# 31999/31999 - 9s - loss: 0.0744 - val_loss: 0.0703
# Epoch 14/50
# 31999/31999 - 9s - loss: 0.0742 - val_loss: 0.0700
# Epoch 15/50
# 31999/31999 - 9s - loss: 0.0740 - val_loss: 0.0699
# Epoch 16/50
# 31999/31999 - 9s - loss: 0.0738 - val_loss: 0.0695
# Epoch 17/50
# 31999/31999 - 9s - loss: 0.0735 - val_loss: 0.0694
# Epoch 18/50
# 31999/31999 - 9s - loss: 0.0734 - val_loss: 0.0692
# Epoch 19/50
# 31999/31999 - 9s - loss: 0.0733 - val_loss: 0.0687
# Epoch 20/50
# 31999/31999 - 9s - loss: 0.0731 - val_loss: 0.0685
# Epoch 21/50
# 31999/31999 - 9s - loss: 0.0730 - val_loss: 0.0681
# Epoch 22/50
# 31999/31999 - 9s - loss: 0.0729 - val_loss: 0.0683
# Epoch 23/50
# 31999/31999 - 9s - loss: 0.0728 - val_loss: 0.0682
# Epoch 24/50
# 31999/31999 - 9s - loss: 0.0727 - val_loss: 0.0679
# Epoch 25/50
# 31999/31999 - 9s - loss: 0.0726 - val_loss: 0.0680
# Epoch 26/50
# 31999/31999 - 9s - loss: 0.0725 - val_loss: 0.0679
# Epoch 27/50
# 31999/31999 - 9s - loss: 0.0724 - val_loss: 0.0677
# Epoch 28/50
# 31999/31999 - 9s - loss: 0.0723 - val_loss: 0.0675
# Epoch 29/50
# 31999/31999 - 9s - loss: 0.0722 - val_loss: 0.0675
# Epoch 30/50
# 31999/31999 - 9s - loss: 0.0721 - val_loss: 0.0676
# Epoch 31/50
# 31999/31999 - 9s - loss: 0.0721 - val_loss: 0.0674
# Epoch 32/50
# 31999/31999 - 9s - loss: 0.0720 - val_loss: 0.0671
# Epoch 33/50
# 31999/31999 - 9s - loss: 0.0719 - val_loss: 0.0673
# Epoch 34/50
# 31999/31999 - 9s - loss: 0.0718 - val_loss: 0.0672
# Epoch 35/50
# 31999/31999 - 9s - loss: 0.0718 - val_loss: 0.0670
# Epoch 36/50
# 31999/31999 - 9s - loss: 0.0717 - val_loss: 0.0669
# Epoch 37/50
# 31999/31999 - 9s - loss: 0.0716 - val_loss: 0.0671
# Epoch 38/50
# 31999/31999 - 9s - loss: 0.0716 - val_loss: 0.0670
# Epoch 39/50
# 31999/31999 - 9s - loss: 0.0715 - val_loss: 0.0668
# Epoch 40/50
# 31999/31999 - 9s - loss: 0.0715 - val_loss: 0.0668
# Epoch 41/50
# 31999/31999 - 9s - loss: 0.0714 - val_loss: 0.0669
# Epoch 42/50
# 31999/31999 - 9s - loss: 0.0714 - val_loss: 0.0669
# Epoch 43/50
# 31999/31999 - 9s - loss: 0.0713 - val_loss: 0.0666
# Epoch 44/50
# 31999/31999 - 9s - loss: 0.0713 - val_loss: 0.0665
# Epoch 45/50
# 31999/31999 - 9s - loss: 0.0712 - val_loss: 0.0666
# Epoch 46/50
# 31999/31999 - 9s - loss: 0.0711 - val_loss: 0.0665
# Epoch 47/50
# 31999/31999 - 9s - loss: 0.0711 - val_loss: 0.0663
# Epoch 48/50
# 31999/31999 - 9s - loss: 0.0710 - val_loss: 0.0663
# Epoch 49/50
# 31999/31999 - 9s - loss: 0.0710 - val_loss: 0.0663
# Epoch 50/50
# 31999/31999 - 9s - loss: 0.0709 - val_loss: 0.0665
# Training time: 0:07:45.726044

# %%
ypred_LSTM = np.zeros((n_train-1, n_pc))

for k in range(n_train-1):
    ypred_LSTM[k,:] = np.squeeze(model.predict(np.expand_dims(x_train[k,:,:], axis=0), batch_size=1))

# %%
for k in range(20):
    plt.plot(y_train[:2000,k])
    plt.plot(ypred_LSTM[:2000,k])
    plt.show()

# %%
# compute LSTM residuals
residual = y_train - ypred_LSTM

# %%
# Spatially correlated white noise
def spatialCorrWhtNoise(nt, npc, residual):
    dW = np.random.randn(nt, npc) # additive white noise
    covn = np.cov(residual.T) # Correlation coefficients
    rr = np.linalg.cholesky(covn)
    stdres = np.std(residual, axis=0)
    return dW.dot(rr.T)*stdres

# %%
################################################################
##################### Short term forecasts #####################
################################################################
n_maxlead = 5  # Prediction of 20 records for each realization
n_ic = int((n_test - n_maxlead))    # Number of initial conditions 
n_ensem = 100
y_pred = np.zeros([n_ic, n_ensem, n_maxlead, n_pc])
isnoise = False
test_dataN = scaler.transform(test_data)

start = datetime.now()
for k in range(n_ic):
    # initial conditions
    x_start = test_dataN[k,:].reshape(1,-1)
    if isnoise:
        # generate the noise for all ensembles
        dW = spatialCorrWhtNoise(n_ensem*n_maxlead, n_pc, residual)
    else:
        # set zero values to the noise component
        dW = np.zeros((n_ensem*n_maxlead, n_pc))
    
    # produce forecasts
    y_pred[k,:,:,:] = forecast(n_maxlead,n_pc,x_start,dt,
                               model,scaler,n_ensem,dW)

enMean_y_pred = np.mean(y_pred, axis=1)
print('Prediction time:', datetime.now()-start)
print('Number of realizations obtained:',n_ic)
print('Prediction length of each realization:',n_maxlead)

# %%
# Plot the predicted results against the truth for any initial condition
ic = 9       # IC index; should be 0,1,2,3..., nic-1 
for k in range(20):
    plt.figure()
    x = np.arange(0,n_maxlead*dt,10)
    plt.plot(x,enMean_y_pred[ic,:,k],label='LSTM')
    true_ = test_data[ic+1:ic+n_maxlead+1,k]
    plt.plot(x,true_,label='Truth')
    plt.xlabel('Time (in days)')
    plt.title('PC#'+str(k))
    plt.legend()
    plt.show()

# %%
####################################################################
############ Metric 1 : RMSE on the physical space #################
###### Use each data point of the test dataset as an IC ############
## Obtain 100 stochastic realizations (if applicable) for each IC ##
####################################################################
# Project the modelled PCs onto the EOFs and calculate mean RMSE
rmse = np.zeros((n_ic, n_maxlead))

start = datetime.now()
# start a parallel pool and implement thread parallelism
if __name__ == "__main__":
    rmse = Parallel(n_jobs=num_cores, prefer="threads")(delayed(RMSE)(i,test_data,enMean_y_pred,eofs,n_maxlead) for i in tqdm(range(n_ic)))

meanRMSE = np.mean(rmse, axis=0)
np.save('RMSE_Psi1_200days_predictions_LSTM_npc=150_nic=9980_nensem=100_ntrain=400K_ntest=100K.dat',meanRMSE)

# %%
# Plot the mean RMSE
plt.plot(np.arange(dt,n_maxlead*dt+1,dt),meanRMSE)
plt.xlabel('Time (in days)')
plt.ylabel('RMSE')
plt.ylim([10, 120])
plt.xlim([dt, n_maxlead*dt])
plt.grid(color='k', linestyle='--', linewidth=0.2)
plt.savefig('RMSE_Psi1_200days_predictions_LSTM_npc=150_nic=9980_nensem=100_ntrain=400K_ntest=100K.png',dpi=100)
plt.show()

# %%
####################################################################
# Metric 2a : Instantaneous temporal correlation coefficient (ITCC) #
####################################################################
itcc = np.zeros((n_ic, nx*ny))

start = datetime.now()
if __name__ == "__main__":
    itcc = Parallel(n_jobs=num_cores, prefer="threads")(delayed(ICC_wrapper)(i,test_data,enMean_y_pred,eofs,n_maxlead,'temporal') for i in tqdm(range(n_ic)))

print('Time taken:',datetime.now()-start)
meanitcc = np.mean(itcc, axis=0)

# %%
plt.imshow(meanitcc.reshape(nx,ny), origin='lower',cmap='jet')
plt.colorbar()
plt.clim([0.2, 0.6])
plt.savefig('ITCC_Psi1_200days_predictions_LSTM_npc=150_nic=9980_ntrain=400K_ntest=100K.png',dpi=100)
plt.show()
np.save('ITCC_Psi1_200days_predictions_LSTM_npc=150_nic=9980_ntrain=400K_ntest=100K',meanitcc)

# %%
####################################################################
# Metric 2b : Instantaneous spatial correlation coefficient (ISCC) #
####################################################################
iscc = np.zeros((n_ic, n_maxlead))

start = datetime.now()
if __name__ == "__main__":
    iscc = Parallel(n_jobs=num_cores, prefer="threads")(delayed(ICC_wrapper)(i,test_data,enMean_y_pred,eofs,n_maxlead,'spatial') for i in tqdm(range(n_ic)))

print('Time taken:',datetime.now()-start)
meaniscc = np.mean(iscc, axis=0)

# %%
plt.plot(np.arange(dt,n_maxlead*dt+1,dt), meaniscc)
plt.xlabel('Time (in days)')
plt.ylabel('ISCC')
plt.xlim([dt, n_maxlead*dt])
plt.grid(color='k', linestyle='--', linewidth=0.2)
plt.savefig('ISCC_Psi1_200days_predictions_LSTM_npc=150_nic=9980_ntrain=400K_ntest=100K.png',dpi=100)
plt.show()
np.save('ISCC_Psi1_200days_predictions_LSTM_npc=150_nic=9980_ntrain=400K_ntest=100K',meaniscc)

# %%
################################################################
############### Long term forecasts: 10,000 days ###############
################################################################
n_maxlead = 1000  # Prediction of 1000 records for each realization
n_ic = 1    # Number of initial conditions 
isnoise = True
n_ensem = 1
y_pred = np.zeros([n_ic, n_ensem, n_maxlead, n_pc])
test_dataN = scaler.transform(test_data)

start = datetime.now()
for k in range(n_ic):
    # initial conditions
    x_start = test_dataN[k,:].reshape(1,-1)
    if isnoise:
        # generate the noise for all ensembles
        dW = spatialCorrWhtNoise(n_ensem*n_maxlead, n_pc, residual)
    else:
        # set zero values to the noise component
        dW = np.zeros((n_ensem*n_maxlead, n_pc))
    
    # produce forecasts
    y_pred[k,:,:,:] = forecast(n_maxlead,n_pc,x_start,dt,
                               model,scaler,n_ensem,dW)

enMean_y_pred = np.mean(y_pred, axis=1)
print('Prediction time:', datetime.now()-start)
print('Number of realizations obtained:',n_ic)
print('Prediction length of each realization:',n_maxlead)
# Out:
# Prediction time: 0:00:24.945389
# Number of realizations obtained: 1
# Prediction length of each realization: 1000

# %%
#############################################################
####### Plot the predicted results against the truth ########
#############################################################
ic = 0       # Should be 0,1,2,3...,nic-1
for k in range(8):
    plt.figure()
    x = np.arange(dt,n_maxlead*dt+1,dt)
    plt.plot(x, y_pred[ic,0,:,k],label='LSTM')
    plt.plot(x, test_data[ic+1:ic+1+n_maxlead,k],label='True')
    plt.title('PC#' + str(k+1))
    plt.xlabel('Time (in days)')
    plt.title('PC#'+str(k))
    plt.legend()
    plt.show()

# %%
################################################################
############# Metric 3 : Climatology and Variance ##############
################ using 10,000 days forecasts  ##################
################################################################
psi1_climatology_pred = np.zeros((n_ic,nx*ny))
psi1_variance_pred = np.zeros((n_ic,nx*ny))

# Project the modelled PCs onto the EOFs and calculate climatology
for kk in range(n_ic):
    psi1_pred = enMean_y_pred[kk,:,:].dot(eofs)
    psi1_climatology_pred[kk,:] = np.mean(psi1_pred, axis=0)
    psi1_variance_pred[kk,:] = np.var(psi1_pred, axis=0)

mean_psi1_climatology_pred = np.mean(psi1_climatology_pred, axis=0)
mean_psi1_variance_pred = np.mean(psi1_variance_pred, axis=0)

# %%
# Climatology and variance of the predictions
plt.imshow(mean_psi1_climatology_pred.reshape(nx,ny), origin='lower', cmap='RdBu')
plt.clim(-50, 50)
plt.colorbar()
plt.savefig('Climatology_Psi1_10Kdays_predictions_LSTM_npc=150_nic=1_nensem=100_ntrain=400K_ntest=100K.png',dpi=100)
plt.show()

plt.imshow(mean_psi1_variance_pred.reshape(nx,ny), origin='lower', cmap='jet')
plt.clim(0, 100000)
plt.colorbar()
plt.savefig('Variance_Psi1_10Kdays_predictions_LSTM_npc=150_nic=1_nensem=100_ntrain=400K_ntest=100K.png',dpi=100)
plt.show()

# %%
##################################################
############# Metric 4: Frequency map ############
####### frequency = 1/decorrelation time #########
##################################################
freq_pred = np.zeros((n_ic,nx*ny))

for kk in range(n_ic):
    psi1_pred = enMean_y_pred[kk,:,:].dot(eofs)
    start = datetime.now()
    if __name__ == "__main__":
        freq_ = Parallel(n_jobs=num_cores, prefer="threads")(delayed(frequency)(i,psi1_pred,dt) for i in tqdm(range(nx*ny)))
    freq_pred[kk,:] = freq_
    print('Time taken:',datetime.now()-start)
    
# mean frequency
mean_freq_pred = np.mean(freq_pred, axis=0)

# %%
plt.imshow(np.array(mean_freq_pred).reshape(nx,ny), origin='lower', cmap='jet')
plt.colorbar()
plt.clim([0,4])
plt.savefig('Frequency_Psi1_10Kdays_predictions_LSTM_npc=150_nic=1_nensem=100_ntrain=400K_ntest=100K.png',dpi=100)
plt.show()
