# %%
##################################################
########### Method: SLR + ANN Hybrid  ############
##################################################
import numpy as np
import matplotlib.pyplot as plt
import math
import json
from netCDF4 import Dataset
from functionsANN_hybrid import *
from scipy import fftpack
from datetime import datetime
import multiprocessing
from joblib import Parallel, delayed
from tqdm import tqdm
# np.random.seed(42)

num_cores = multiprocessing.cpu_count()
print('Number of cores:',num_cores)

# Define other parameters of the problem
n_pc = 150         # number of PCs
n_record = 50000   # total records
n_maxtrain = 40000 # maximum possible length of training data
n_test = n_record - n_maxtrain # length of the test data
test0_idx = 40000              # test data start index
dt = 10            # temporal resolution

#### Load the pcs ####
f = 'psi1_DG_0_500K_100days_filtered_150PCs.dat'
fpath = os.getcwd() + '/../' + f
pcs = dlmread(fpath,n_record,n_pc)
pcs = center(pcs)
# get the test dataset
test_data = pcs[test0_idx:test0_idx+n_test, :]
 
#### Load the EOFs ####
nx = 513; ny=513
eoffile = os.getcwd() + '/../psi1_DG_0_500K_100days_filtered_150EOFs.nc'
fid = Dataset(eoffile,'r')
eofs = fid.variables['EOFs'][:n_pc,:,:]
eofs = eofs.reshape((n_pc, nx*ny))
# Out:
# Using TensorFlow backend.
# Number of cores: 24

# %%
# train the LR
n_train = n_maxtrain # Length used for training
[x_train, y_train, scaler_x] = training4tendency(pcs, n_pc, n_train, dt, 'standard_top_pc')
# Train the LR
start = datetime.now()
[linregmodel, linregres, r2_sco] = linear_regression(x_train, y_train)
print('LR training time:',datetime.now()-start)
# Out:
# LR training time: 0:00:00.605316

# %%
# plot LR output vs the truth
y_tend_LR = linregmodel.predict(x_train)
for k in range(10):
    plt.plot(y_train[:2000,k])
    plt.plot(y_tend_LR[:2000,k])
    plt.show()

# %%
# normalize the linear regression residuals
scaler_linregres = StandardScaler()
scaler_linregres.fit(np.tile(linregres[:,0].reshape(-1,1),(1,n_pc)))
linregresN = scaler_linregres.transform(linregres)

# %%
x_train_ANN = np.hstack([x_train[:-1,:],linregresN[:-1,:]])
y_train_ANN = linregresN[1:,:]

# %%
# Train the Neural Network
start = datetime.now()

hyperparams = {'activation':'tanh', 'npl':200, 
               'loss':'mae', 'optimizer':'SGD',
               'metric':'mae', 'epochs':200,
               'numhidlayers':1,'validation_split':0.2}

model, history = ANN(x_train_ANN,y_train_ANN,n_pc,**hyperparams)

print('ANN Training time:',datetime.now()-start)

# plot history
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Test')
plt.legend()
plt.show()
# Out:
# Train on 31998 samples, validate on 8000 samples
# Epoch 1/200
# 31998/31998 [==============================] - 3s 101us/step - loss: 0.5691 - mae: 0.5691 - val_loss: 0.5548 - val_mae: 0.5548
# Epoch 2/200
# 31998/31998 [==============================] - 3s 96us/step - loss: 0.5273 - mae: 0.5273 - val_loss: 0.5238 - val_mae: 0.5238
# Epoch 3/200
# 31998/31998 [==============================] - 3s 95us/step - loss: 0.5013 - mae: 0.5013 - val_loss: 0.5024 - val_mae: 0.5024
# Epoch 4/200
# 31998/31998 [==============================] - 3s 94us/step - loss: 0.4827 - mae: 0.4827 - val_loss: 0.4864 - val_mae: 0.4864
# Epoch 5/200
# 31998/31998 [==============================] - 3s 94us/step - loss: 0.
200
# 31998/31998 [==============================] - 3s 94us/step - loss: 0.3351 - mae: 0.3351 - val_loss: 0.3510 - val_mae: 0.3510
# Epoch 197/200
# 31998/31998 [==============================] - 3s 94us/step - loss: 0.3351 - mae: 0.3351 - val_loss: 0.3509 - val_mae: 0.3509
# Epoch 198/200
# 31998/31998 [==============================] - 3s 94us/step - loss: 0.3350 - mae: 0.3350 - val_loss: 0.3508 - val_mae: 0.3508
# Epoch 199/200
# 31998/31998 [==============================] - 3s 94us/step - loss: 0.3349 - mae: 0.3349 - val_loss: 0.3508 - val_mae: 0.3508
# Epoch 200/200
# 31998/31998 [==============================] - 3s 95us/step - loss: 0.3348 - mae: 0.3348 - val_loss: 0.3507 - val_mae: 0.3507
# ANN Training time: 0:10:03.445754

# %%
# check the ANN training
# plot the ANN outputs vs the truth
y_out_ANN = np.zeros((n_train-2, n_pc))

for k in range(n_train-2):
    y_out_ANN[k,:] = model.predict(np.reshape(x_train_ANN[k,:], [1,-1]), batch_size=1)

# %%
for k in range(30):
    plt.plot(y_train_ANN[:2000,k], label='Truth')
    plt.plot(y_out_ANN[:2000,k],label='ANN')
    plt.legend()
    plt.show()

# %%
# calculate ANN residuals
ANNres = y_train_ANN - y_out_ANN

# %%
#### ANN output diagnostics ####
# 1. autocorrelation
n_maxlag = 1000
acorr_ANN = tsaplots.acf(y_out_ANN[:,-1], nlags=n_maxlag, fft=False)
acorr_truth = tsaplots.acf(y_train_ANN[:,-1], nlags=n_maxlag, fft=False)
plt.plot(acorr_ANN[:50], label='ANN')
plt.plot(acorr_truth[:50], label='Truth')
plt.title('Autocorrelation')
plt.legend()
plt.show()

# 2. spatial correlation matrix
covn_ANN = np.corrcoef(y_out_ANN.T) # Correlation coefficients
covn_truth = np.corrcoef(y_train_ANN.T) # Correlation coefficients
fig, (ax1, ax2) = plt.subplots(1,2)
f = ax1.matshow(covn_ANN, vmin=-0.5, vmax=0.5)
ax1.set_title('Covariance - ANN')
ax1.xaxis.set_ticks_position('bottom')
f = ax2.matshow(covn_truth, vmin=-0.5, vmax=0.5)
ax2.set_title('Covariance - Truth')
ax2.xaxis.set_ticks_position('bottom')
fig.colorbar(f, ax=(ax1,ax2),orientation='horizontal')
plt.show()

# 3. Mean
plt.scatter(range(n_pc),np.mean(y_out_ANN, axis=0), label='ANN')
plt.scatter(range(n_pc),np.mean(y_train_ANN, axis=0), label='Truth')
plt.legend()
plt.title('Mean')
plt.show()

# 4. standard deviation
plt.scatter(range(n_pc),np.std(y_out_ANN, axis=0), label='ANN')
plt.scatter(range(n_pc),np.std(y_train_ANN, axis=0), label='Truth')
plt.legend()
plt.title('Standard deviation')
plt.show()

# %%
# plot LR+ANN output for the training data
y_out_ANN = scaler_linregres.inverse_transform(y_out_ANN)
y_pred_hybrid = (y_tend_LR[1:,:] + y_out_ANN)*dt + x_train[1:,:]

for k in range(20):
    plt.plot(y_pred_hybrid[:,k])
    plt.plot(x_train[2:,k])
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-9004267cb0fa> in <module>
#       1 # plot LR+ANN output for the training data
#       2 y_out_ANN = scaler_linregres.inverse_transform(y_out_ANN)
# ----> 3 y_pred_hybrid = (y_tend_LR[1:,:] + y_out_ANN)*dt + x_train[1:,:]
#       4
#       5 for k in range(20):
#
# NameError: name 'y_tend_LR' is not defined

# %%
# Spatially correlated white noise
def spatialCorrWhtNoise(nt, npc, residual):
    dW = np.random.randn(nt, npc) # additive white noise
    covn = np.corrcoef(residual.T) # Correlation coefficients
    rr = np.linalg.cholesky(covn)
    stdres = np.std(residual, axis=0)
    return dW.dot(rr.T)*stdres

# %%
####################################################################
#####################  Short term forecasts ########################
####################################################################   
n_maxlead = 5  # Prediction of 20 records for each realization
n_ic = int((n_test - n_maxlead - 2))     # Number of initial conditions
n_ensem = 100
y_pred = np.zeros([n_ic, n_ensem, n_maxlead, n_pc])
isnoise = False
test_dataN = scaler_x.transform(test_data)

start = datetime.now()
for k in range(10):
    # initial conditions
    x_now = test_dataN[k+1:k+2,:]
    x_prev = test_dataN[k:k+1,:]
    res_now = (x_now - x_prev)/dt - linregmodel.predict(x_now)
    res_now = scaler_linregres.transform(res_now)
    
    ann_icond = np.hstack([x_now, res_now])
    LR_icond = x_now[-1,:].reshape(1,-1)
    
    if isnoise:
        # generate the noise for all ensembles
        dW = spatialCorrWhtNoise(n_ensem*n_maxlead, n_pc, ANNres)
    else:
        # set zero values to the noise component
        dW = np.zeros((n_ensem*n_maxlead, n_pc))
    
    # produce forecasts
    y_pred[k,:,:,:] = forecast_hybrid(n_maxlead,n_pc,LR_icond,ann_icond,
                                      dt,model,linregmodel,scaler_x,
                                      scaler_linregres,n_ensem,dW)

enMean_y_pred = np.mean(y_pred, axis=1)
print('Prediction time:', datetime.now()-start)
print('Number of initial conditions:',n_ic)
print('Number of realizations obtained:',n_ic)
print('Prediction length of each realization:',n_maxlead)
# Out:
# Prediction time: 0:00:24.470952
# Number of initial conditions: 9978
# Number of realizations obtained: 9978
# Prediction length of each realization: 20

# %%
# Plot the predicted results against the truth for any initial condition
ic = 0       # IC index; should be 0,1,2,3..., nic-1 
for k in range(20):
    plt.figure()
    x = np.arange(0,n_maxlead*dt,10)
    plt.plot(x,enMean_y_pred[ic,:,k],label='ANN Hybrid')
    true_ = test_data[ic+2:ic+n_maxlead+2,k]
    plt.plot(x,true_,label='Truth')
    plt.xlabel('Time (in days)')
    plt.title('PC#'+str(k))
    plt.legend()
    plt.show()

# %%
####################################################################
############ Metric 1 : RMSE on the physical space #################
###### Use each data point of the test dataset as an IC ############
## Obtain 100 stochastic realizations (if applicable) for each IC ##
####################################################################
# Project the modelled PCs onto the EOFs and calculate mean RMSE
rmse = np.zeros((n_ic, n_maxlead))

start = datetime.now()
# start a parallel pool and implement thread parallelism
if __name__ == "__main__":
    rmse = Parallel(n_jobs=num_cores, prefer="threads")(delayed(RMSE)(i,test_data,enMean_y_pred,eofs,n_maxlead) for i in tqdm(range(n_ic)))

meanRMSE = np.mean(rmse, axis=0)
np.save('RMSE_Psi1_200days_predictions_ANN_hybrid_npc=150_nic=9980_nensem=100_ntrain=400K_ntest=100K',meanRMSE)

# %%
# Plot the mean RMSE
plt.plot(np.arange(dt,n_maxlead*dt+1,dt),meanRMSE)
plt.xlabel('Time (in days)')
plt.ylabel('RMSE')
plt.ylim([10, 120])
plt.xlim([dt, n_maxlead*dt])
plt.grid(color='k', linestyle='--', linewidth=0.2)
plt.savefig('RMSE_Psi1_200days_predictions_ANN_hybrid_npc=150_nic=9980_nensem=100_ntrain=400K_ntest=100K.png',dpi=100)
plt.show()

# %%
####################################################################
# Metric 2a : Instantaneous temporal correlation coefficient (ITCC) #
####################################################################
itcc = np.zeros((n_ic, nx*ny))

start = datetime.now()
if __name__ == "__main__":
    itcc = Parallel(n_jobs=num_cores, prefer="threads")(delayed(ICC_wrapper)(i,test_data,enMean_y_pred,eofs,n_maxlead,'temporal') for i in tqdm(range(n_ic)))

print('Time taken:',datetime.now()-start)
meanitcc = np.mean(itcc, axis=0)

# %%
plt.imshow(meanitcc.reshape(nx,ny), origin='lower',cmap='jet')
plt.colorbar()
plt.clim([0.2, 0.6])
plt.savefig('ITCC_Psi1_200days_predictions_ANN_hybrid_npc=150_nic=9980_ntrain=400K_ntest=100K.png',dpi=100)
plt.show()
np.save('ITCC_Psi1_200days_predictions_ANN_hybrid_npc=150_nic=9980_ntrain=400K_ntest=100K',meanitcc)

# %%
####################################################################
# Metric 2b : Instantaneous spatial correlation coefficient (ISCC) #
####################################################################
iscc = np.zeros((n_ic, n_maxlead))

start = datetime.now()
if __name__ == "__main__":
    iscc = Parallel(n_jobs=num_cores, prefer="threads")(delayed(ICC_wrapper)(i,test_data,enMean_y_pred,eofs,n_maxlead,'spatial') for i in tqdm(range(n_ic)))

print('Time taken:',datetime.now()-start)
meaniscc = np.mean(iscc, axis=0)

# %%
plt.plot(np.arange(dt,n_maxlead*dt+1,dt), meaniscc)
plt.xlabel('Time (in days)')
plt.ylabel('ISCC')
plt.xlim([dt, n_maxlead*dt])
plt.grid(color='k', linestyle='--', linewidth=0.2)
plt.savefig('ISCC_Psi1_200days_predictions_ANN_hybrid_npc=150_nic=9980_ntrain=400K_ntest=100K.png',dpi=100)
plt.show()
np.save('ISCC_Psi1_200days_predictions_ANN_hybrid_npc=150_nic=9980_ntrain=400K_ntest=100K',meaniscc)

# %%
################################################################
############### Long term forecasts: 10,000 days ###############
################################################################
n_maxlead = 1000  # Prediction of 1000 records for each realization
n_ic = 1     # Number of initial conditions
n_ensem = 1
y_pred = np.zeros([n_ic, n_ensem, n_maxlead, n_pc])
isnoise = True
test_dataN = scaler_x.transform(test_data)

for k in range(n_ic):
    # initial conditions
    x_now = test_dataN[k+1:k+2,:]
    x_prev = test_dataN[k:k+1,:]
    res_now = (x_now - x_prev)/dt - linregmodel.predict(x_now)
    res_now = scaler_linregres.transform(res_now)
    
    ann_icond = np.hstack([x_now, res_now])
    LR_icond = x_now[-1,:].reshape(1,-1)
    
    start = datetime.now()
    if isnoise:
        # generate the noise for all ensembles
        dW = spatialCorrWhtNoise(n_ensem*n_maxlead, n_pc, ANNres)
    else:
        # set zero values to the noise component
        dW = np.zeros((n_ensem*n_maxlead, n_pc))
    print('Noise generation time:',datetime.now()-start)
    
    start = datetime.now()
    # produce forecasts
    y_pred[k,:,:,:] = forecast_hybrid(n_maxlead,n_pc,LR_icond,ann_icond,
                                      dt,model,linregmodel,scaler_x,
                                      scaler_linregres,n_ensem,dW)
    print('Prediction time:',datetime.now()-start)

enMean_y_pred = np.mean(y_pred, axis=1)
print('Number of initial conditions:',n_ic)
print('Number of realizations obtained:',n_ic)
print('Prediction length of each realization:',n_maxlead)
# Out:
# Noise generation time: 0:00:00.111630
# Prediction time: 0:00:01.010374
# Number of initial conditions: 1
# Number of realizations obtained: 1
# Prediction length of each realization: 1000

# %%
###### Time complexity ######
# Pure LR+ANN hybrid
# Training time = LR training (0.6sec) + ANN training (~600sec for 200 epochs)
# Prediction time = time to produce one 10K days realization using one initial condition (1 sec)
#
# LR + ANN + Noise hybrid
# Training time = LR training (0.6sec) + ANN training (~600sec for 200 epochs) + time to calculate the standard deviations of ANN residuals (0.2sec)
# Prediction time = time to produce one 10K days realization using one initial condition(1 sec)+ noise generation time (0.1sec)

# %%
#############################################################
####### Plot the predicted results against the truth ########
#############################################################
ic = 0       # Should be 0,1,2,3...,nic-1
for k in range(0,20):
    plt.figure()
    x = np.arange(dt,n_maxlead*dt+1,dt)
    plt.plot(x, enMean_y_pred[ic,:,k],label='ANN Hybrid')
    #plt.plot(x, enMean_y_pred[ic,:,k],label='ANN Hybrid')
    plt.plot(x, test_data[ic+2:ic+2+n_maxlead,k],label='True')
    plt.title('PC#' + str(k+1))
    plt.xlabel('Time (in days)')
    plt.title('PC#'+str(k))
    plt.legend()
    plt.show()

# %%
################################################################
############# Metric 3 : Climatology and Variance ##############
######### using multiple realizations of 10,000 days  #########
################################################################
psi1_climatology_pred = np.zeros((n_ic,nx*ny))
psi1_variance_pred = np.zeros((n_ic,nx*ny))

# Project the modelled PCs onto the EOFs and calculate climatology
for kk in range(n_ic):
    psi1_pred = enMean_y_pred[kk,:,:].dot(eofs)
    psi1_climatology_pred[kk,:] = np.mean(psi1_pred, axis=0)
    psi1_variance_pred[kk,:] = np.var(psi1_pred, axis=0)

mean_psi1_climatology_pred = np.mean(psi1_climatology_pred, axis=0)
mean_psi1_variance_pred = np.mean(psi1_variance_pred, axis=0)

# %%
# Climatology and variance of the predictions
plt.imshow(mean_psi1_climatology_pred.reshape(nx,ny), origin='lower', cmap='RdBu')
plt.clim(-50, 50)
plt.colorbar()
plt.savefig('Climatology_Psi1_10Kdays_predictions_ANN_hybrid_npc=150_nic=1_nensem=100_ntrain=400K_ntest=100K.png',dpi=100)
plt.show()

plt.imshow(mean_psi1_variance_pred.reshape(nx,ny), origin='lower', cmap='jet')
plt.clim(0, 100000)
plt.colorbar()
plt.savefig('Variance_Psi1_10Kdays_predictions_ANN_hybrid_npc=150_nic=1_nensem=100_ntrain=400K_ntest=100K.png',dpi=100)
plt.show()

# %%
##################################################
############# Metric 4: Frequency map ############
####### frequency = 1/decorrelation time #########
##################################################
freq_pred = np.zeros((n_ic,nx*ny))

for kk in range(n_ic):
    psi1_pred = enMean_y_pred[kk,:,:].dot(eofs)
    start = datetime.now()
    if __name__ == "__main__":
        freq_ = Parallel(n_jobs=num_cores, prefer="threads")(delayed(frequency)(i,psi1_pred,dt) for i in tqdm(range(nx*ny)))
    freq_pred[kk,:] = freq_
    print('Time taken:',datetime.now()-start)
    
# mean frequency
mean_freq_pred = np.mean(freq_pred, axis=0)

# %%
plt.imshow(np.array(mean_freq_pred).reshape(nx,ny), origin='lower', cmap='jet')
plt.colorbar()
plt.clim([0,4])
plt.savefig('Frequency_Psi1_10Kdays_predictions_ANN_hybrid_npc=150_nic=1_nensem=100_ntrain=400K_ntest=100K.png',dpi=100)
plt.show()
